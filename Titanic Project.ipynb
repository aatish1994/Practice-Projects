# %%
#Importing required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#Loading dataset
data=pd.read_csv('titanic_train.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1         0       3
# 1           1            2         1       1
# 2           2            3         1       3
# 3           3            4         1       1
# 4           4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
#checking shape
data.shape
# Out:
# (891, 13)

# %% [markdown]
# In this dataset there are 891 rows and 13 columns.

# %%
#Checking Null values
data.isna().sum()
# Out:
# Unnamed: 0       0
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# we can see that in age there are 177 null values, in cabin there are 687 and in embarked there are 2 null values.

# %%
#Checking for data types
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   891 non-null    int64
#  1   PassengerId  891 non-null    int64
#  2   Survived     891 non-null    int64
#  3   Pclass       891 non-null    int64
#  4   Name         891 non-null    object
#  5   Sex          891 non-null    object
#  6   Age          714 non-null    float64
#  7   SibSp        891 non-null    int64
#  8   Parch        891 non-null    int64
#  9   Ticket       891 non-null    object
#  10  Fare         891 non-null    float64
#  11  Cabin        204 non-null    object
#  12  Embarked     889 non-null    object
# dtypes: float64(2), int64(6), object(5)
# memory usage: 90.6+ KB

# %% [markdown]
# unnamed, passengerId,Survived,pclass,sibsp,parch this all have integer data types.
# while name,sex,ticket,cabin,embarked this have string data types,
# age and fare have float data types

# %%
#Description of dataset
data.describe()
# Out:
#        Unnamed: 0  PassengerId    Survived      Pclass         Age  \
# count  891.000000   891.000000  891.000000  891.000000  714.000000
# mean   445.000000   446.000000    0.383838    2.308642   29.699118
# std    257.353842   257.353842    0.486592    0.836071   14.526497
# min      0.000000     1.000000    0.000000    1.000000    0.420000
# 25%    222.500000   223.500000    0.000000    2.000000   20.125000
# 50%    445.000000   446.000000    0.000000    3.000000   28.000000
# 75%    667.500000   668.500000    1.000000    3.000000   38.000000
# max    890.000000   891.000000    1.000000    3.000000   80.000000
#
#             SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000
# mean     0.523008    0.381594   32.204208
# std      1.102743    0.806057   49.693429
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    7.910400
# 50%      0.000000    0.000000   14.454200
# 75%      1.000000    0.000000   31.000000
# ...

# %%
#Removing unwanted columns
data=data.drop(['Unnamed: 0','PassengerId'],axis=1)

# %%
#checking whether the data is removed or not
data.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %% [markdown]
# by looking at the we can see that unnamed and passenger id column has been removed

# %%
#Checking for duplicates
data.drop_duplicates(inplace=True)

# %%
#checking rows to check whether there was any duplicates were present or not
data.shape
# Out:
# (891, 11)

# %% [markdown]
# there were no duplicates present

# %% [markdown]
# # since there are lot of null values present in cabin almost 70% null values are there, and i dont find it that important for prediction that is why iam droping the cabin column

# %%
#Dropping column cabin
data=data.drop(['Cabin'],axis=1)

# %%
#checking whether it is deleted or not
data.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500        S
# 1  female  38.0      1      0          PC 17599  71.2833        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250        S
# 3  female  35.0      1      0            113803  53.1000        S
# 4    male  35.0      0      0            373450   8.0500        S

# %% [markdown]
# It has been removed

# %% [markdown]
# # Since there are null values present in the  age and embarked, so first i will fix them

# %%
#replcing the null values of age column by using mean 
data['Age']=data['Age'].fillna(data['Age'].mean())

# %%
#replacing the null values of embarked column by using mode
data['Embarked']=data['Embarked'].fillna(data['Embarked'].mode()[0])

# %%
#Checking for null values whether they are replaced or not
data.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    0
# dtype: int64

# %% [markdown]
# we can see that there are no null values present

# %%
#checking the unique values of column Survived
data['Survived'].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# There are two unique values present in column survived that is 0 and 1, 0 mean dead and 1 mean survived.

# %%
#Checking the values of column Pclass
data['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %% [markdown]
# There are three unique values present in column pclass that is 3 mean third class, 2 means second class and 1 mean first class.

# %%
#Checking the unique values of column Sex
data['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %% [markdown]
# There are two unique values present in column sex that is male and and female.

# %%
#Checking How many numbers of unique values present in 'Age'
data['Age'].nunique()
# Out:
# 89

# %% [markdown]
# Threre are about 89 age category people were present in the dataset

# %%
#Checkin Unique values of SibSp
data['SibSp'].unique()
# Out:
# array([1, 0, 3, 4, 2, 5, 8], dtype=int64)

# %% [markdown]
# This are the numbers of siblings or spouse

# %%
#Checking unique values of Parch
data['Parch'].unique()
# Out:
# array([0, 1, 2, 5, 3, 4, 6], dtype=int64)

# %% [markdown]
# This are the numbers of parents or childrens

# %%
#Checking unique values of Ticket
data['Ticket'].unique()
# Out:
# array(['A/5 21171', 'PC 17599', 'STON/O2. 3101282', '113803', '373450',
#        '330877', '17463', '349909', '347742', '237736', 'PP 9549',
#        '113783', 'A/5. 2151', '347082', '350406', '248706', '382652',
#        '244373', '345763', '2649', '239865', '248698', '330923', '113788',
#        '347077', '2631', '19950', '330959', '349216', 'PC 17601',
#        'PC 17569', '335677', 'C.A. 24579', 'PC 17604', '113789', '2677',
#        'A./5. 2152', '345764', '2651', '7546', '11668', '349253',
#        'SC/Paris 2123', '330958', 'S.C./A.4. 23567', '370371', '14311',
#        '2662', '349237', '3101295', 'A/4. 39886', 'PC 17572', '2926',
#        '113509', '19947', 'C.A. 31026', '2697', 'C.A. 34651', 'CA 2144',
#        '2669', '113572', '36973', '347088', 'PC 17605', '2661',
#        'C.A. 29395', 'S.P. 3464', '3101281', '315151', 'C.A. 33111',
#        'S.O.C. 14879', '2680', '1601', '348123', '349208', '374746',
# ...

# %% [markdown]
# This are different ticket numbers

# %%
#Cheking unique values of Fare
data['Fare'].unique()
# Out:
# array([  7.25  ,  71.2833,   7.925 ,  53.1   ,   8.05  ,   8.4583,
#         51.8625,  21.075 ,  11.1333,  30.0708,  16.7   ,  26.55  ,
#         31.275 ,   7.8542,  16.    ,  29.125 ,  13.    ,  18.    ,
#          7.225 ,  26.    ,   8.0292,  35.5   ,  31.3875, 263.    ,
#          7.8792,   7.8958,  27.7208, 146.5208,   7.75  ,  10.5   ,
#         82.1708,  52.    ,   7.2292,  11.2417,   9.475 ,  21.    ,
#         41.5792,  15.5   ,  21.6792,  17.8   ,  39.6875,   7.8   ,
#         76.7292,  61.9792,  27.75  ,  46.9   ,  80.    ,  83.475 ,
#         27.9   ,  15.2458,   8.1583,   8.6625,  73.5   ,  14.4542,
#         56.4958,   7.65  ,  29.    ,  12.475 ,   9.    ,   9.5   ,
#          7.7875,  47.1   ,  15.85  ,  34.375 ,  61.175 ,  20.575 ,
#         34.6542,  63.3583,  23.    ,  77.2875,   8.6542,   7.775 ,
#         24.15  ,   9.825 ,  14.4583, 247.5208,   7.1417,  22.3583,
#          6.975 ,   7.05  ,  14.5   ,  15.0458,  26.2833,   9.2167,
# ...

# %% [markdown]
# This are different passenger fares

# %%
#Checking unique values of Embarked
data['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %% [markdown]
# There are three unique values present in embarked C = Cherbourg; Q = Queenstown; S = Southampton

# %%
#Checking how many people survived and how many people died
data.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# It shows that 549 people died and 342 people survived

# %%
#ploting count plot to visualize
sns.countplot(x='Survived',data=data)
plt.show()

# %% [markdown]
# This plot shows how many people were survived and how many people were dead.so by looking we can say that more number of people were dead as compared to survived.

# %%
#Checking How many males and females were there
data.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
#Plotting count plot to visualize
sns.countplot(x='Sex',data=data)
plt.show()

# %% [markdown]
# by looking at the plot its comes to our notice that males were more than females

# %%
#Checking How mnay female and male survived and dead 
data.groupby('Sex')['Survived'].value_counts()
# Out:
# Sex     Survived
# female  1           233
#         0            81
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %% [markdown]
# So we can see that 233 females survived and 81 of them died and 468 men died and 109 men survived.so most of the females were survived and more number of males died

# %%
#Ploting bar plot to check how many males and females surived and died
#Died=0
#Survived=1
data.groupby('Sex')['Survived'].value_counts().plot.barh()
plt.show()

# %% [markdown]
# over here also we can see that most of the males died and most of the females survived

# %%
#plotting countplot
sns.countplot(x='Survived',hue='Sex',data=data)
plt.show()

# %% [markdown]
# over here we can see that most of the males dies and very few males survived.
# And most of the females survived in camparison to the females which died.

# %%
#Checking Mean of survived people accoridng to sex
data.groupby('Sex')[['Survived']].mean()
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %% [markdown]
# Mean of female survived is 0.74 and mean of male survived is 0.18

# %%
#Checking the number of people thatw ere present in particulaer classes
data.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %% [markdown]
# In third class 491 people were there, in second class 184 people were there and in first class 216 people were there.

# %%
#Plotting the countplot for Pclass
sns.countplot(x='Pclass',data=data)
plt.show()

# %% [markdown]
# We can see that most of the people were present in the third class followed by first class and least in the second class

# %%
#Checking how many females and males were present in each of the classes
data.groupby('Sex')['Pclass'].value_counts()
# Out:
# Sex     Pclass
# female  3         144
#         1          94
#         2          76
# male    3         347
#         1         122
#         2         108
# Name: Pclass, dtype: int64

# %% [markdown]
# we can see that 144 females and 347 males were there in third class, 76 females and 108 males were there in second class and 94 females and 122 males were there in first class

# %%
#Plotting barplot to check how many males and females were there in particular classes
data.groupby('Sex')['Pclass'].value_counts().plot.barh()
plt.show()

# %% [markdown]
# so we can see that  more number of males and females were there in third class.
# Less number of males and Females were present in second class as compared to First and third class

# %%
#Checking how many people survived and died from each of the classes
data.groupby('Pclass')['Survived'].value_counts()
# Out:
# Pclass  Survived
# 1       1           136
#         0            80
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: Survived, dtype: int64

# %% [markdown]
# It shows that 136 people survived and 80 people died from first class, 87 people survived and 97 people died from second class and 119 people survived and 372 people died from second class. so we can say that most of the people were dead from third class and most of the people were survived from first class

# %%
#Ploting bar plot to check how many of the people died and survived from each of the classes
#For Pclass
#1=First class
#2=Second class
#3=Third class
#For Survived
#0=Dead
#1=Survived
data.groupby('Pclass')['Survived'].value_counts().plot.barh()
plt.show()

# %% [markdown]
# We can see that from third class most of the people died and from first class most of the people survived

# %%
#Plotting countplot
sns.countplot(x='Survived',hue='Pclass',data=data)
plt.show()

# %% [markdown]
# In this we can see that most of the people from third class died and most of the people from first class survived

# %%
data.groupby('Sex')['Survived','Pclass',].value_counts()
# Out:
# Sex     Survived  Pclass
# female  1         1          91
#         0         3          72
#         1         3          72
#                   2          70
#         0         2           6
#                   1           3
# male    0         3         300
#                   2          91
#                   1          77
#         1         3          47
#                   1          45
#                   2          17
# dtype: int64

# %% [markdown]
# In this we can see that:
# From first class 91 females and 77 males survived and 3 females and 77 males died.
# From second class 70 females and 17 males survived and 6 females and 91 males died.
# From third class 72 females and 47 males survived and 72 females and 300 males died.

# %%
#Ploting bar plot to check how many males and fermales from particular classes survived and died
#For Pclass
#1=First class
#2=Second class
#3=Third class
#For Survived
#0=Dead
#1=Survived
data.groupby('Sex')['Survived','Pclass',].value_counts().plot.barh()
plt.show()

# %% [markdown]
# we can see more number of males from third class died as compared to second and third class.
# And more number of females from third class died as compared to second and third class.
# And about survival,males from third and first class have more over equal number number of survived males.
# and for females more number of them died from third class.

# %%
#Checking nymber of siblings/spouses
data.SibSp.value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %% [markdown]
# In this we can see the number of siblings/spouse present in the dataset,it seems most of the people were not having any siblings or spouse and 7 people were having higheest number of siblings/spouse in the dataset i.e 8

# %%
#Checking countplot for sibling/spouse
sns.countplot(x='SibSp',data=data)
plt.show()

# %% [markdown]
# In this we can clearly see that most of the people were not having any siblings/spouse.

# %%
#Plotting Countplot to visualize the male and female
sns.countplot(x='Sex',hue='SibSp',data=data)
plt.show()

# %%
#Checking numbers of parents/childrens
data.Parch.value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %% [markdown]
# In this we can see the number of parents/childrens present in the dataset,by looking at the counts we can say that most of the people are not having any parents or childrens and 1 of them were having 6 family members which inlude parents as well as childrens.

# %%
#Plotting countplot for Parch
sns.countplot(x='Parch',data=data)
plt.show()

# %% [markdown]
# We can clearly see that most of the people are not haivng parents and childrens.

# %%
#Checking how many male and females parents/childresn were there
sns.countplot(x='Sex',hue='Parch',data=data)
plt.show()

# %%
sns.countplot(x='Survived',hue='Parch',data=data)
plt.show()

# %%
#Checking the number of people boarded from southampton,cherbough and queenstown
data.Embarked.value_counts()
# Out:
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %% [markdown]
# we can see that most of the people i.e 646 boarded from southampton, followed by cherbough i.e 168 and least boarded from Queenstown i.e 77

# %%
#Plotting countplot for Embarked
sns.countplot(x='Embarked',data=data)
plt.show()

# %% [markdown]
# We can clearly see that most of the people boarded from Southampton and least from Queenstown

# %%
#Checking the number of people dided and survived from a particular ports
data.groupby('Embarked')['Survived'].value_counts()
# Out:
# Embarked  Survived
# C         1            93
#           0            75
# Q         0            47
#           1            30
# S         0           427
#           1           219
# Name: Survived, dtype: int64

# %% [markdown]
# In this we can see that:
# Most of the people i.e 427 died which boarded from Southampton and less number of people i.e 47 died which boarded from Queenstown.
# most of the people i.e 219 survived which boarded from southampton and less number of people i.e 30 survived which boarded from Queenstown

# %%
#Plotting Barplot to check how many people survived and died from particular ports
data.groupby('Embarked')['Survived'].value_counts().plot.barh()
plt.show()

# %% [markdown]
# In this we can see that most of the people died which boarded from Southampton and least which boarded from Queenstown.
# And most of them survived which boarded from Southampton and least which boarded from Queenstown.

# %%
#plotting countplot to Check how may people died which boarded from a particular port
sns.countplot(x='Survived',hue='Embarked',data=data)
plt.show()

# %% [markdown]
# So in this we can see that most of the people died and survivied from the southampton port.
# And least died and survived from the queenstown port.

# %%
#Plotting countplot to check how many males and females were there which boarded from a particular port
sns.countplot(x='Sex',hue='Embarked',data=data)
plt.show()

# %% [markdown]
# Most of the males and females boarded from southampton port.
# And least boarded from queenstown port

# %%
#Ploting bar plot to check how many males and fermales from particular classes survived and died
#For Embarked
#S=Southampton
#C=Cherbough
#Q=Queenstown
#For Survived
#0=Dead
#1=Survived
data.groupby('Sex')['Survived','Embarked',].value_counts()
# Out:
# Sex     Survived  Embarked
# female  1         S           142
#                   C            64
#         0         S            63
#         1         Q            27
#         0         C             9
#                   Q             9
# male    0         S           364
#         1         S            77
#         0         C            66
#                   Q            38
#         1         C            29
#                   Q             3
# dtype: int64

# %% [markdown]
# In this we can see that:
# Most of the females survived i.e 142 which boarded from Southampton and least survived i.e 27 which boarded from Queenstown.
# whereas most of the females died i.e 63 which boarded from Southampton and least died i.e 9 each which boarded from Cherbough and Queenstown.
#
# Most of the males survived i.e 77 which boarded from Southampton and least survived i.e 3 which boarded from Queenstown.
# And most of the males died i.e 364 which boarded from Southampton and leasr died i.e 38 which boarded from Queentown.

# %%
#Plotting Barplot to check how many males and females died and survived which boarded from a particular ports
#For Embarked
#S=Southampton
#C=Cherbough
#Q=Queenstown
#For Survived
#0=Dead
#1=Survived
data.groupby('Sex')['Survived','Embarked',].value_counts().plot.barh()
plt.show()

# %% [markdown]
# so we can see that:
# Most of the males died which boarded from Southampton and least died which boarded from Queenstown
# Most of the males survived which boarded from Southampton and least survived which boarded from Queenstown
#
# Most females died which boarded from Southampton and least died which boarded from Queenstown.
# Most of the females survived which boarded from Southampton and least survived from Queentown.
#
# So we can see that most of males and females died and survived which boarded from Southampton.
# And least of them died which boarded from Queenstown

# %%
#Checking the mean for age
data['Age'].mean()
# Out:
# 29.699117647058763

# %% [markdown]
# So the mean age meaning most of the people which were there of more over of the age 29.
# 29.69 is the mean.

# %%
#Checking the mean of the people survived as per to pclass
data.groupby('Pclass')[['Survived']].mean()
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %% [markdown]
# So we can see that highest mean is of first class means most of the people survived from the first class and least from the third class.

# %%
#Plotting pie chart to visualize the mean percentage of people survived as per to pclass
Pclass=['1 = First Class', '2 = Second Class', '3 = Third Class']
x=[0.629630,0.472826,0.242363]
plt.pie(x,labels=Pclass,autopct='%.2f',explode=[0.1,0,0])
plt.show()

# %% [markdown]
# This is the average of people i.e mean percentage of people who survived from specific Pclass.
# So highest mean percentage of people who survived  is of first class and least survived from Third class.

# %%
#Checking the mean of the people survived as per to Embarked
#S=Southampton
#C=Cherbough
#Q=Queenstown
data.groupby('Embarked')[['Survived']].mean()
# Out:
#           Survived
# Embarked
# C         0.553571
# Q         0.389610
# S         0.339009

# %% [markdown]
# We can see that highest mean is of Cherbough and least is of Southampton

# %%
#Plotting pie chart to visualize the mean percentage of people survived as per to Embarked
Embarked=['C = Cherbourg', 'Q = Queenstown', 'S = Southampton']
x=[0.553571,0.389610,0.336957]
plt.pie(x,labels=Embarked,autopct='%.2f',explode=[0.1,0,0])
plt.show()

# %% [markdown]
# This is the average of people i.e mean percentage of people who survived which boarded from specific ports. So highest mean percentage of people who survived which boarded from Cherbough and least survived which boarded from Southampton.

# %%
#Since column Sex and Embarked have categorical values so using label encoder to encode
#Importing required libraries
from sklearn.preprocessing import LabelEncoder

# %%
#Encoding column Sex
lab_enc=LabelEncoder()
df=lab_enc.fit_transform(data['Sex'])

# %%
#Transfering data to column Sex
data['Sex']=df

# %%
#Chekcing the whether the data is encoded or not
data.head()
# Out:
#    Survived  Pclass                                               Name  Sex  \
# 0         0       3                            Braund, Mr. Owen Harris    1
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0
# 2         1       3                             Heikkinen, Miss. Laina    0
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0
# 4         0       3                           Allen, Mr. William Henry    1
#
#     Age  SibSp  Parch            Ticket     Fare Embarked
# 0  22.0      1      0         A/5 21171   7.2500        S
# 1  38.0      1      0          PC 17599  71.2833        C
# 2  26.0      0      0  STON/O2. 3101282   7.9250        S
# 3  35.0      1      0            113803  53.1000        S
# 4  35.0      0      0            373450   8.0500        S

# %% [markdown]
# We can see that column sex data is encoded

# %%
#Encoding column Embarked
df1=lab_enc.fit_transform(data['Embarked'])

# %%
#Transfering data to column Embarked
data['Embarked']=df1

# %%
#Chekcing the whether the data is encoded or not
data.head()
# Out:
#    Survived  Pclass                                               Name  Sex  \
# 0         0       3                            Braund, Mr. Owen Harris    1
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0
# 2         1       3                             Heikkinen, Miss. Laina    0
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0
# 4         0       3                           Allen, Mr. William Henry    1
#
#     Age  SibSp  Parch            Ticket     Fare  Embarked
# 0  22.0      1      0         A/5 21171   7.2500         2
# 1  38.0      1      0          PC 17599  71.2833         0
# 2  26.0      0      0  STON/O2. 3101282   7.9250         2
# 3  35.0      1      0            113803  53.1000         2
# 4  35.0      0      0            373450   8.0500         2

# %% [markdown]
# We can see that column Embarked data is encoded

# %%
#checking correlation
data.corr()
# Out:
#           Survived    Pclass       Sex       Age     SibSp     Parch  \
# Survived  1.000000 -0.338481 -0.543351 -0.069809 -0.035322  0.081629
# Pclass   -0.338481  1.000000  0.131900 -0.331339  0.083081  0.018443
# Sex      -0.543351  0.131900  1.000000  0.084153 -0.114631 -0.245489
# Age      -0.069809 -0.331339  0.084153  1.000000 -0.232625 -0.179191
# SibSp    -0.035322  0.083081 -0.114631 -0.232625  1.000000  0.414838
# Parch     0.081629  0.018443 -0.245489 -0.179191  0.414838  1.000000
# Fare      0.257307 -0.549500 -0.182333  0.091566  0.159651  0.216225
# Embarked -0.167675  0.162098  0.108262 -0.026749  0.068230  0.039798
#
#               Fare  Embarked
# Survived  0.257307 -0.167675
# Pclass   -0.549500  0.162098
# Sex      -0.182333  0.108262
# Age       0.091566 -0.026749
# SibSp     0.159651  0.068230
# Parch     0.216225  0.039798
# Fare      1.000000 -0.224719
# Embarked -0.224719  1.000000

# %%
#plotting correlation
data.drop(['Survived'],axis=1).corrwith(data['Survived']).plot(kind='bar',grid=True,figsize=(15,5),title='Correlation with Survived')
plt.show()

# %% [markdown]
# so in this we can see that sibsp column is less correlated to survived that is label and sex column is highly negatively correlated to survived that is label

# %%
#plotting heatmap
corr=data.corr().abs()
plt.figure(figsize=(20,10))
sns.heatmap(corr,annot=True)
plt.show()

# %% [markdown]
# As we can see that there is  no multicollinearity within the features.

# %%
#Plotting dist plot for Age
sns.distplot(data['Age'],kde=True)
plt.show()

# %% [markdown]
# In this we can see that most of the people were from age between 20 years to 40 years.and we can see some skewness.so we will confirm this by using skewness method

# %%
#Plotting dist plot for Age
sns.distplot(data['Fare'],kde=True)
plt.show()

# %% [markdown]
# In this plot we can see the right skewed data. we will confirm this in skewness method

# %%
#Checking skewness
data.skew()
# Out:
# Survived    0.478523
# Pclass     -0.630548
# Sex        -0.618921
# Age         0.434488
# SibSp       3.695352
# Parch       2.749117
# Fare        4.787317
# Embarked   -1.264823
# dtype: float64

# %% [markdown]
# since survived is label and pclass,sibsp,parch,sex and embarked are categorical data so we wont treat skewness for this column.
#
# And for Age the value is 0.43 which is below 0.5, so it shows that it does'nt have any skewness and it has a normal distribution.
# For fare the skewness is more than 0.5 so we need to treat the skewnees of fare.

# %%
df=data[['Fare']]

# %%
#Transforming the data of fare using power transform method to remove skewness
#Importing required libraries
from sklearn.preprocessing import power_transform
df=power_transform(df,method='yeo-johnson')
df
# Out:
# array([[-0.87882001],
#        [ 1.33665056],
#        [-0.79006485],
#        [ 1.06735243],
#        [-0.77443897],
#        [-0.72500246],
#        [ 1.04551561],
#        [ 0.18426413],
#        [-0.44994393],
#        [ 0.53017623],
#        [-0.04548834],
#        [ 0.40978768],
#        [-0.77443897],
#        [ 0.56794581],
#        [-0.7990223 ],
#        [-0.08799901],
#        [ 0.49936669],
#        [-0.29490695],
#        [ 0.02877395],
#        [-0.88225884],
#        [ 0.38946249],
#        [-0.29490695],
#        [-0.77702262],
#        [ 0.68918281],
#        [ 0.18426413],
#        [ 0.57139509],
#        [-0.88225884],
#        [ 2.45146557],
#        [-0.79585041],
#        [-0.79374968],
#        [ 0.45160947],
#        [ 1.9680262 ],
#        [-0.81234947],
#        [-0.50858175],
#        [ 1.46433   ],
#        [ 1.04796949],
#        [-0.88168032],
#        [-0.77443897],
#        [ 0.02877395],
#        [-0.44024445],
#        [-0.6114356 ],
# ...

# %%
#Transferring the transformed data to fare column
data['Fare']=df

# %%
#Checking skewness
data.skew()
# Out:
# Survived    0.478523
# Pclass     -0.630548
# Sex        -0.618921
# Age         0.434488
# SibSp       3.695352
# Parch       2.749117
# Fare       -0.040329
# Embarked   -1.264823
# dtype: float64

# %% [markdown]
# So we can see that now the skewness of the fare is between 0.5 to -0.5. so that means skewness have been removed from column fare

# %%
#Plotting dist plot for Age
sns.distplot(data['Fare'],kde=True)
plt.show()

# %% [markdown]
# as we can that its not totally a normal dustribution but somewhat and as we look previous plot we can see that skewness have be removed

# %%
#Checking outliers for age
data['Age'].plot.box()
plt.show()

# %% [markdown]
# outliers are present

# %%
data['Fare'].plot.box()
plt.show()

# %% [markdown]
# Outliers are present

# %%
#using zscore method to remove outliers
from scipy.stats import zscore

# %%
z_score=zscore(data[['Age','Fare']])
abs_z_score=np.abs(z_score)
threshold=3
z=(abs_z_score<3).all(axis=1)

# %%
data=data[z]

# %%
#checking rows and columns
data.shape
# Out:
# (869, 10)

# %% [markdown]
# so we can say that outliers have been removed

# %%
#Percentage Loss of Data
data_loss=((891-869)/891)*100
print(f'Data Loss:{data_loss} %')
# Out:
# Data Loss:2.4691358024691357 %

# %%
#Dropping usesless columns
data=data.drop(['Name','Ticket'],axis=1)

# %%
data.shape
# Out:
# (869, 8)

# %%
#Dividing dataset into features and label
#Features
x=data.drop(['Survived'],axis=1)
#Label
y=data['Survived']

# %%
#Importing required libraries
from sklearn.preprocessing import StandardScaler

# %%
#using standardization method to standardize the data
scaler=StandardScaler()
x_scaler=scaler.fit_transform(x)
x_scaler
# Out:
# array([[ 0.81638557,  0.75217403, -0.58296583, ..., -0.47967653,
#         -1.04871818,  0.59099658],
#        [-1.58442342, -1.32947957,  0.69273222, ..., -0.47967653,
#          1.42769844, -1.92653296],
#        [ 0.81638557, -1.32947957, -0.26404132, ..., -0.47967653,
#         -0.94950912,  0.59099658],
#        ...,
#        [ 0.81638557, -1.32947957,  0.0308935 , ...,  1.97955006,
#          0.2565237 ,  0.59099658],
#        [-1.58442342,  0.75217403, -0.26404132, ..., -0.47967653,
#          0.52369681, -1.92653296],
#        [ 0.81638557,  0.75217403,  0.21434545, ..., -0.47967653,
#         -0.9744185 , -0.66776819]])

# %%
#Importing required libraries
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_curve,roc_auc_score
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# # LOGISTIC REGRESSION

# %%
#Initiating Logistic Regression
lr=LogisticRegression()

# %%
#using range fucntion to find the best random state using Logestic regression
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(x_scaler,y,test_size=0.25,random_state=i)
    lr.fit(x_train,y_train)
    pred=lr.predict(x_train)
    y_pred=lr.predict(x_test)
    print(f'at random state{i},the training accuracy is:{accuracy_score(y_train,pred)*100}')
    print(f'at random state{i},the testing accuracy is:{accuracy_score(y_test,y_pred)*100}')
    print('\n')
# Out:
# at random state0,the training accuracy is:80.79877112135176
# at random state0,the testing accuracy is:75.22935779816514
#
#
# at random state1,the training accuracy is:81.41321044546851
# at random state1,the testing accuracy is:71.55963302752293
#
#
# at random state2,the training accuracy is:80.3379416282642
# at random state2,the testing accuracy is:75.68807339449542
#
#
# at random state3,the training accuracy is:79.4162826420891
# at random state3,the testing accuracy is:77.98165137614679
#
#
# at random state4,the training accuracy is:80.79877112135176
# at random state4,the testing accuracy is:77.98165137614679
#
#
# at random state5,the training accuracy is:78.64823348694317
# at random state5,the testing accuracy is:80.73394495412845
#
#
# at random state6,the training accuracy is:80.03072196620585
# at random state6,the testing accuracy is:79.81651376146789
#
#
# at random state7,the training accuracy is:81.5668202764977
# ...

# %% [markdown]
# Taking the random state=6

# %%
#Training Testing and Spliting the data
x_train,x_test,y_train,y_test=train_test_split(x_scaler,y,test_size=0.25,random_state=6)

# %%
#Building Model to test unexposed data
def metric_score(clf,x_train,x_test,y_train,y_test,train=True):
    if train:
        pred=clf.predict(x_train)
        print('\n=====Train Score=====')
        print(f'Accuracy Score:{accuracy_score(y_train,pred)*100:.2f}%')
    elif train==False:
        y_pred=clf.predict(x_test)
        print('\n=====Test Score=====')
        print(f'Accuracy Score:{accuracy_score(y_test,y_pred)*100:.2f}%')
        print('\n Test Classification Report:\n',classification_report(y_test,y_pred,digits=2))
        print('\n Confusion Matrix:\n',confusion_matrix(y_test,y_pred))

# %%
#Training the data
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
#calling the function and passing the dataset for logistic regression
metric_score(lr,x_train,x_test,y_train,y_test,train=True)#for training
metric_score(lr,x_train,x_test,y_train,y_test,train=False)#for testing
# Out:
# =====Train Score=====
# Accuracy Score:80.03%
#
# =====Test Score=====
# Accuracy Score:79.82%
#
#  Test Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.83      0.82       124
#            1       0.77      0.76      0.76        94
#
#     accuracy                           0.80       218
#    macro avg       0.79      0.79      0.79       218
# weighted avg       0.80      0.80      0.80       218
#
#
#  Confusion Matrix:
#  [[103  21]
#  [ 23  71]]

# %% [markdown]
# For Logistic Regression:
# we can see that the training score i am getting is 80.03% and testing score is 79.82% which is very good. but it can be a case of overfitting so i will be checking it with cross validation score.

# %%
#Checking Cross Validation score
#Importing required libraries
from sklearn.model_selection import cross_val_score

# %%
y_pred=lr.predict(x_test)
test_accuracy=accuracy_score(y_test,y_pred)

# %%
#Checking cross validation score
for j in range(2,6):
    cv_score=cross_val_score(lr,x_scaler,y,cv=j)
    cv_mean=cv_score.mean()
    print(f'at cross fold {j} the cv score is{cv_mean}and accuracy for the testing is {test_accuracy}')
    print('\n')
# Out:
# at cross fold 2 the cv score is0.7882620901530801and accuracy for the testing is 0.7981651376146789
#
#
# at cross fold 3 the cv score is0.7882790438690689and accuracy for the testing is 0.7981651376146789
#
#
# at cross fold 4 the cv score is0.7974992601361349and accuracy for the testing is 0.7981651376146789
#
#
# at cross fold 5 the cv score is0.784844860806591and accuracy for the testing is 0.7981651376146789

# %% [markdown]
# By looking at the output i will be talking cv=4.

# %% [markdown]
# # KNEIGHNORS CLASSIFIER

# %%
#Instantiating the models
knn=KNeighborsClassifier()

# %%
#using range fucntion to find the best random state using KNeighborsClassifier
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(x_scaler,y,test_size=0.25,random_state=i)
    knn.fit(x_train,y_train)
    pred=knn.predict(x_train)
    y_pred=knn.predict(x_test)
    print(f'at random state{i},the training accuracy is:{accuracy_score(y_train,pred)*100}')
    print(f'at random state{i},the testing accuracy is:{accuracy_score(y_test,y_pred)*100}')
    print('\n')
# Out:
# at random state0,the training accuracy is:88.63287250384025
# at random state0,the testing accuracy is:72.47706422018348
#
#
# at random state1,the training accuracy is:86.32872503840245
# at random state1,the testing accuracy is:74.31192660550458
#
#
# at random state2,the training accuracy is:85.71428571428571
# at random state2,the testing accuracy is:80.27522935779817
#
#
# at random state3,the training accuracy is:85.25345622119815
# at random state3,the testing accuracy is:82.11009174311926
#
#
# at random state4,the training accuracy is:85.40706605222735
# at random state4,the testing accuracy is:79.81651376146789
#
#
# at random state5,the training accuracy is:85.40706605222735
# at random state5,the testing accuracy is:80.27522935779817
#
#
# at random state6,the training accuracy is:86.32872503840245
# at random state6,the testing accuracy is:78.44036697247707
#
#
# at random state7,the training accuracy is:85.25345622119815
# ...

# %% [markdown]
# Taking the random state=10

# %%
#Training the data
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
#calling the function and passing the dataset for KNN
metric_score(knn,x_train,x_test,y_train,y_test,train=True)#for training
metric_score(knn,x_train,x_test,y_train,y_test,train=False)#for testing
# Out:
# =====Train Score=====
# Accuracy Score:85.41%
#
# =====Test Score=====
# Accuracy Score:80.73%
#
#  Test Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.86      0.85       134
#            1       0.76      0.73      0.74        84
#
#     accuracy                           0.81       218
#    macro avg       0.80      0.79      0.79       218
# weighted avg       0.81      0.81      0.81       218
#
#
#  Confusion Matrix:
#  [[115  19]
#  [ 23  61]]

# %% [markdown]
# For KNNeighborsClassifier:
# we can see that training score we are getting is 85.41% and testing score 80.73%.

# %%
y_pred=knn.predict(x_test)
test_accuracy=accuracy_score(y_test,y_pred)

# %%
#Checking cross validation score
for j in range(2,6):
    cv_score=cross_val_score(knn,x_scaler,y,cv=j)
    cv_mean=cv_score.mean()
    print(f'at cross fold {j} the cv score is{cv_mean}and accuracy for the testing is {test_accuracy}')
    print('\n')
# Out:
# at cross fold 2 the cv score is0.8009243074315378and accuracy for the testing is 0.8073394495412844
#
#
# at cross fold 3 the cv score is0.8020801018176034and accuracy for the testing is 0.8073394495412844
#
#
# at cross fold 4 the cv score is0.8055690610070605and accuracy for the testing is 0.8073394495412844
#
#
# at cross fold 5 the cv score is0.8043917347684539and accuracy for the testing is 0.8073394495412844

# %% [markdown]
# By looking at the output i will be talking cv=4.

# %% [markdown]
# # DECISIONTREE CLASSIFIER

# %%
#Instantiating the models
dt=DecisionTreeClassifier()

# %%
#using range fucntion to find the best random state using DecisionTreeClassifier
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(x_scaler,y,test_size=0.25,random_state=i)
    dt.fit(x_train,y_train)
    pred=dt.predict(x_train)
    y_pred=dt.predict(x_test)
    print(f'at random state{i},the training accuracy is:{accuracy_score(y_train,pred)*100}')
    print(f'at random state{i},the testing accuracy is:{accuracy_score(y_test,y_pred)*100}')
    print('\n')
# Out:
# at random state0,the training accuracy is:98.15668202764977
# at random state0,the testing accuracy is:74.77064220183486
#
#
# at random state1,the training accuracy is:98.61751152073732
# at random state1,the testing accuracy is:71.10091743119266
#
#
# at random state2,the training accuracy is:98.0030721966206
# at random state2,the testing accuracy is:78.44036697247707
#
#
# at random state3,the training accuracy is:98.0030721966206
# at random state3,the testing accuracy is:76.60550458715596
#
#
# at random state4,the training accuracy is:98.61751152073732
# at random state4,the testing accuracy is:77.06422018348624
#
#
# at random state5,the training accuracy is:98.31029185867895
# at random state5,the testing accuracy is:77.06422018348624
#
#
# at random state6,the training accuracy is:98.31029185867895
# at random state6,the testing accuracy is:73.39449541284404
#
#
# at random state7,the training accuracy is:98.31029185867895
# ...

# %% [markdown]
# Taking the random state=109

# %%
#Training the data
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
#calling the function and passing the dataset for DecisionTreeClassifier
metric_score(dt,x_train,x_test,y_train,y_test,train=True)#for training
metric_score(dt,x_train,x_test,y_train,y_test,train=False)#for testing
# Out:
# =====Train Score=====
# Accuracy Score:99.08%
#
# =====Test Score=====
# Accuracy Score:78.44%
#
#  Test Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82       134
#            1       0.71      0.74      0.73        84
#
#     accuracy                           0.78       218
#    macro avg       0.77      0.78      0.77       218
# weighted avg       0.79      0.78      0.79       218
#
#
#  Confusion Matrix:
#  [[109  25]
#  [ 22  62]]

# %% [markdown]
# For DecisionTreeClassifier: we can see that training score we are getting is 99.08% and testing score 78.44%

# %%
y_pred=dt.predict(x_test)
test_accuracy=accuracy_score(y_test,y_pred)

# %%
#Checking cross validation score
for j in range(2,6):
    cv_score=cross_val_score(dt,x_scaler,y,cv=j)
    cv_mean=cv_score.mean()
    print(f'at cross fold {j} the cv score is{cv_mean}and accuracy for the testing is {test_accuracy}')
    print('\n')
# Out:
# at cross fold 2 the cv score is0.7399173685046877and accuracy for the testing is 0.8073394495412844
#
#
# at cross fold 3 the cv score is0.7617985125084518and accuracy for the testing is 0.8073394495412844
#
#
# at cross fold 4 the cv score is0.7572295269099056and accuracy for the testing is 0.8073394495412844
#
#
# at cross fold 5 the cv score is0.7744734569131619and accuracy for the testing is 0.8073394495412844

# %% [markdown]
# By looking at the output i will be talking cv=5.

# %% [markdown]
# # RANDOMFOREST CLASSIFIER

# %%
#Instantiating the models
rfc=RandomForestClassifier()

# %%
#using range fucntion to find the best random state using RandomForestClassifier
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(x_scaler,y,test_size=0.25,random_state=i)
    rfc.fit(x_train,y_train)
    pred=rfc.predict(x_train)
    y_pred=rfc.predict(x_test)
    print(f'at random state{i},the training accuracy is:{accuracy_score(y_train,pred)*100}')
    print(f'at random state{i},the testing accuracy is:{accuracy_score(y_test,y_pred)*100}')
    print('\n')
# Out:
# at random state0,the training accuracy is:98.0030721966206
# at random state0,the testing accuracy is:75.22935779816514
#
#
# at random state1,the training accuracy is:98.61751152073732
# at random state1,the testing accuracy is:77.06422018348624
#
#
# at random state2,the training accuracy is:98.0030721966206
# at random state2,the testing accuracy is:79.35779816513761
#
#
# at random state3,the training accuracy is:98.0030721966206
# at random state3,the testing accuracy is:82.56880733944955
#
#
# at random state4,the training accuracy is:98.61751152073732
# at random state4,the testing accuracy is:77.52293577981652
#
#
# at random state5,the training accuracy is:98.31029185867895
# at random state5,the testing accuracy is:80.27522935779817
#
#
# at random state6,the training accuracy is:98.31029185867895
# at random state6,the testing accuracy is:83.4862385321101
#
#
# at random state7,the training accuracy is:98.31029185867895
# ...

# %% [markdown]
# Taking the random state=62

# %%
#Training the data
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
#calling the function and passing the dataset for RandomForestClassifier
metric_score(rfc,x_train,x_test,y_train,y_test,train=True)#for training
metric_score(rfc,x_train,x_test,y_train,y_test,train=False)#for testing
# Out:
# =====Train Score=====
# Accuracy Score:99.08%
#
# =====Test Score=====
# Accuracy Score:81.19%
#
#  Test Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.88      0.85       134
#            1       0.79      0.70      0.74        84
#
#     accuracy                           0.81       218
#    macro avg       0.81      0.79      0.80       218
# weighted avg       0.81      0.81      0.81       218
#
#
#  Confusion Matrix:
#  [[118  16]
#  [ 25  59]]

# %% [markdown]
# For RandomForestClassifier: we can see that training score are getting is 99.08% and testing score 81.19%

# %%
y_pred=rfc.predict(x_test)
test_accuracy=accuracy_score(y_test,y_pred)

# %%
#Checking cross validation score
for j in range(2,6):
    cv_score=cross_val_score(rfc,x_scaler,y,cv=j)
    cv_mean=cv_score.mean()
    print(f'at cross fold {j} the cv score is{cv_mean}and accuracy for the testing is {test_accuracy}')
    print('\n')
# Out:
# at cross fold 2 the cv score is0.7836590921129297and accuracy for the testing is 0.8119266055045872
#
#
# at cross fold 3 the cv score is0.7963210436304339and accuracy for the testing is 0.8119266055045872
#
#
# at cross fold 4 the cv score is0.7998456855367183and accuracy for the testing is 0.8119266055045872
#
#
# at cross fold 5 the cv score is0.8021061723473523and accuracy for the testing is 0.8119266055045872

# %% [markdown]
# By looking at the output i will be talking cv=5.

# %%
#Making dataframe of all the models
data=pd.DataFrame({
    'Models':['Logistic','KNN','Decision Tree','Random Forest'],
    'Training Score':[80.03,85.41,99.08,99.08],
    'Testing Score':[79.82,80.73,78.44,81.19],
    'Cross Val Score':[79.74,80.55,77.44,80.21]
})
data
# Out:
#           Models  Training Score  Testing Score  Cross Val Score
# 0       Logistic           80.03          79.82            79.74
# 1            KNN           85.41          80.73            80.55
# 2  Decision Tree           99.08          78.44            77.44
# 3  Random Forest           99.08          81.19            80.21

# %% [markdown]
# # I am choosing Random Forest Classifier as it has seen most of the data and testing score and cross validation score is aslo good. Mainly i am selecting thism model because of the confusion matrix.Because the FP and FN score is less.

# %%
#Using Grid Search cv for hyperparameter tuning for RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# %%
param_grid=({
    'n_estimators': [200, 500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [4,5,6,7,8],
    'criterion' :['gini', 'entropy']
})

# %%
grid_search=GridSearchCV(rfc,param_grid=param_grid,cv=5)

# %%
#Training
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [4, 5, 6, 7, 8],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [200, 500]})

# %%
#best Parameters
grid_search.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 8,
#  'max_features': 'auto',
#  'n_estimators': 200}

# %%
#Training with the best parameters
rfc=RandomForestClassifier(criterion='entropy',max_depth=8,max_features='auto',n_estimators=200)
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=8, max_features='auto',
#                        n_estimators=200)

# %% [markdown]
# I have choosed criterion entropy ovwe gini because it gives me good result.

# %%
#calling the function and passing the dataset
metric_score(rfc,x_train,x_test,y_train,y_test,train=True)#Training Score
metric_score(rfc,x_train,x_test,y_train,y_test,train=False)#Testing Score
# Out:
# =====Train Score=====
# Accuracy Score:91.86%
#
# =====Test Score=====
# Accuracy Score:85.32%
#
#  Test Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.93      0.89       134
#            1       0.86      0.74      0.79        84
#
#     accuracy                           0.85       218
#    macro avg       0.86      0.83      0.84       218
# weighted avg       0.85      0.85      0.85       218
#
#
#  Confusion Matrix:
#  [[124  10]
#  [ 22  62]]

# %%
#plotting roc curve
fpr,tpr,threshold=roc_curve(y_test,y_pred)

# %%
print('FPR',fpr)
print('TPR',tpr)
print('Threshold',threshold)
# Out:
# FPR [0.         0.11940299 1.        ]
# TPR [0.         0.70238095 1.        ]
# Threshold [2 1 0]

# %%
plt.plot(fpr,tpr,color='orange',label='ROC')
plt.plot([0,1],[0,1],color='blue',linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# %%
#Checking AUC Score
roc_auc_score=roc_auc_score(y_test,y_pred)
roc_auc_score
# Out:
# 0.7914889836531627

# %%
#saving the model
#Importing required libraries
import pickle
pickle.dump(rfc,open('Titanic Project','wb'))
