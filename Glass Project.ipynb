# %% [markdown]
# # Problem Statement:
# The dataset describes the chemical properties of glass and involves classifying samples of glass using their chemical properties as one of six classes. The dataset was credited to Vina Spiehler in 1987. The study of classification of types of glass was motivated by criminological investigation. At the scene of the crime, the glass left can be used as evidence...if it is correctly identified!

# %%
#Importing Required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#Loading Dataset
data=pd.read_csv('Glass.csv')

# %%
#Checking overview of the dataset
data.head()
# Out:
#    1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 0  2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83   0.0    0.00    1
# 1  3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78   0.0    0.00    1
# 2  4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22   0.0    0.00    1
# 3  5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07   0.0    0.00    1
# 4  6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07   0.0    0.26    1

# %%
#Checking the shape of the dataset
data.shape
# Out:
# (213, 11)

# %% [markdown]
# **Since the data does not have the column name so iam creating the new column with the names and transferring the data into new columns and than dropping the old columns.**

# %%
data['id_number']=data['1']

# %%
data['RI']=data['1.52101']

# %%
data['Na']=data['13.64']

# %%
data['Mg']=data['4.49']

# %%
data['Al']=data['1.10']

# %%
data['Si']=data['71.78']

# %%
data['K']=data['0.06']

# %%
data['Ca']=data['8.75']

# %%
data['Ba']=data['0.00']

# %%
data['Fe']=data['0.00.1']

# %%
data['type_of_glass']=data['1.1']

# %%
data.head()
# Out:
#    1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  ...  \
# 0  2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83   0.0    0.00  ...
# 1  3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78   0.0    0.00  ...
# 2  4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22   0.0    0.00  ...
# 3  5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07   0.0    0.00  ...
# 4  6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07   0.0    0.26  ...
#
#         RI     Na    Mg    Al     Si     K    Ca   Ba    Fe  type_of_glass
# 0  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.00              1
# 1  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.00              1
# 2  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.00              1
# 3  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.00              1
# 4  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.0  0.26              1
#
# [5 rows x 22 columns]

# %% [markdown]
# * **So we can see that the data have been transferred to the new columns, so dropping the old columns.**

# %%
#Dropping old columns
data=data.drop(['1','1.52101','13.64','4.49','1.10','71.78','0.06','8.75','0.00','0.00.1','1.1'],axis=1)

# %%
data.head()
# Out:
#    id_number       RI     Na    Mg    Al     Si     K    Ca   Ba    Fe  \
# 0          2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.00
# 1          3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.00
# 2          4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.00
# 3          5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.00
# 4          6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.0  0.26
#
#    type_of_glass
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
#Checking the shape
data.shape
# Out:
# (213, 11)

# %% [markdown]
# * **So we can see that there  are about 213 rows and 11 columns**

# %%
#Checking the names of the columns
data.columns
# Out:
# Index(['id_number', 'RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe',
#        'type_of_glass'],
#       dtype='object')

# %% [markdown]
# * **There are 11 columns in the datasets. They are:
# id_number:Numbers of the data,  RI: refractive index, Na: Sodium (unit measurement: weight percent in corresponding oxide, as are attributes 4-10), Mg: Magnesium, Al: Aluminum, Si: Silicon, K: Potassium, Ca: Calcium, Ba: Barium, Fe: Iron, Type of glass: (class attribute)**

# %%
#Checking for the null values
data.isna().sum()
# Out:
# id_number        0
# RI               0
# Na               0
# Mg               0
# Al               0
# Si               0
# K                0
# Ca               0
# Ba               0
# Fe               0
# type_of_glass    0
# dtype: int64

# %% [markdown]
# * **So we can see that null values are not present in the dataset**

# %%
#Checking data types of columns
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id_number      213 non-null    int64
#  1   RI             213 non-null    float64
#  2   Na             213 non-null    float64
#  3   Mg             213 non-null    float64
#  4   Al             213 non-null    float64
#  5   Si             213 non-null    float64
#  6   K              213 non-null    float64
#  7   Ca             213 non-null    float64
#  8   Ba             213 non-null    float64
#  9   Fe             213 non-null    float64
#  10  type_of_glass  213 non-null    int64
# dtypes: float64(9), int64(2)
# memory usage: 18.4 KB

# %%
#Description of the dateset
data.describe()
# Out:
#         id_number          RI          Na          Mg          Al          Si  \
# count  213.000000  213.000000  213.000000  213.000000  213.000000  213.000000
# mean   108.000000    1.518353   13.406761    2.676056    1.446526   72.655023
# std     61.631972    0.003039    0.818371    1.440453    0.499882    0.774052
# min      2.000000    1.511150   10.730000    0.000000    0.290000   69.810000
# 25%     55.000000    1.516520   12.900000    2.090000    1.190000   72.280000
# 50%    108.000000    1.517680   13.300000    3.480000    1.360000   72.790000
# 75%    161.000000    1.519150   13.830000    3.600000    1.630000   73.090000
# max    214.000000    1.533930   17.380000    3.980000    3.500000   75.410000
#
#                 K          Ca          Ba          Fe  type_of_glass
# count  213.000000  213.000000  213.000000  213.000000     213.000000
# mean     0.499108    8.957934    0.175869    0.057277       2.788732
# ...

# %% [markdown]
# * **Most of the columns have foat data type and only id number and type of glass column have integer data type**

# %%
#Removing unwanted column
data=data.drop(['id_number'],axis=1)
data.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba    Fe  type_of_glass
# 0  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.00              1
# 1  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.00              1
# 2  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.00              1
# 3  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.00              1
# 4  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.0  0.26              1

# %% [markdown]
# * **So we can see that the id_number column have been dropped from the dataset.**

# %%
#Checking if there are any duplicates in dataset
data.drop_duplicates(inplace=True)
data.shape
# Out:
# (212, 10)

# %% [markdown]
# * **So we can see that number of rows reduced from 213 to 212, so there was one duplicate present in the dataset.**

# %%
#Checking for unique values
data['RI'].unique()
# Out:
# array([1.51761, 1.51618, 1.51766, 1.51742, 1.51596, 1.51743, 1.51756,
#        1.51918, 1.51755, 1.51571, 1.51763, 1.51589, 1.51748, 1.51784,
#        1.52196, 1.51911, 1.51735, 1.5175 , 1.51966, 1.51736, 1.51751,
#        1.5172 , 1.51764, 1.51793, 1.51721, 1.51768, 1.51747, 1.51775,
#        1.51753, 1.51783, 1.51567, 1.51909, 1.51797, 1.52213, 1.51779,
#        1.5221 , 1.51786, 1.519  , 1.51869, 1.52667, 1.52223, 1.51898,
#        1.5232 , 1.51926, 1.51808, 1.51837, 1.51778, 1.51769, 1.51215,
#        1.51824, 1.51754, 1.51905, 1.51977, 1.52172, 1.52227, 1.52099,
#        1.52152, 1.523  , 1.51574, 1.51848, 1.51593, 1.51631, 1.5159 ,
#        1.51645, 1.51627, 1.51613, 1.51592, 1.51646, 1.51594, 1.51409,
#        1.51625, 1.51569, 1.5164 , 1.51841, 1.51605, 1.51588, 1.51629,
#        1.5186 , 1.51689, 1.51811, 1.51655, 1.5173 , 1.5182 , 1.52725,
#        1.5241 , 1.52475, 1.53125, 1.53393, 1.52222, 1.51818, 1.52664,
# ...

# %%
#Checking for number of  unique values present 
data['RI'].nunique()
# Out:
# 177

# %% [markdown]
# * **There are about 177 unique numbers present in RI column.**

# %%
#Checking for unique values
data['Na'].unique()
# Out:
# array([13.89, 13.53, 13.21, 13.27, 12.79, 13.3 , 13.15, 14.04, 13.  ,
#        12.72, 12.8 , 12.88, 12.86, 12.61, 12.81, 12.68, 14.36, 13.9 ,
#        13.02, 12.82, 14.77, 12.78, 13.38, 12.98, 12.87, 12.56, 13.08,
#        12.65, 12.84, 12.85, 12.57, 12.69, 13.29, 12.74, 14.21, 12.71,
#        13.73, 12.73, 13.49, 13.19, 13.99, 13.58, 13.72, 13.2 , 13.43,
#        13.14, 12.45, 12.99, 13.48, 13.39, 13.6 , 13.81, 13.51, 14.17,
#        13.69, 13.05, 13.12, 13.31, 14.86, 13.64, 13.09, 13.34, 13.44,
#        13.92, 13.25, 13.41, 14.25, 13.36, 13.24, 13.4 , 13.01, 12.55,
#        12.93, 12.9 , 12.2 , 12.67, 12.96, 12.75, 12.35, 12.62, 13.8 ,
#        13.83, 11.45, 10.73, 12.3 , 14.43, 11.23, 11.02, 12.64, 13.46,
#        13.1 , 13.56, 13.23, 12.94, 13.78, 13.55, 13.98, 13.75, 13.7 ,
#        13.71, 13.33, 12.89, 13.65, 12.16, 14.32, 13.42, 13.04, 14.03,
#        13.5 , 14.19, 14.01, 11.56, 11.03, 12.97, 14.  , 13.79, 14.46,
# ...

# %%
#Checking for number of  unique values present 
data['Na'].nunique()
# Out:
# 142

# %% [markdown]
# * **So there are about 142 unique values present in column in Na**

# %%
#Checking for unique values
data['Mg'].unique()
# Out:
# array([3.6 , 3.55, 3.69, 3.62, 3.61, 3.58, 3.46, 3.66, 3.43, 3.56, 3.59,
#        3.54, 3.67, 3.85, 3.73, 3.75, 3.57, 3.5 , 3.48, 3.52, 3.49, 3.47,
#        3.45, 3.53, 3.82, 3.42, 3.39, 3.84, 3.37, 3.7 , 3.77, 3.35, 3.72,
#        3.33, 2.87, 2.84, 2.81, 2.71, 3.74, 3.86, 3.81, 3.65, 3.87, 3.09,
#        3.44, 3.41, 3.34, 3.25, 2.88, 2.96, 2.85, 2.72, 2.76, 3.15, 2.9 ,
#        0.  , 3.83, 3.97, 3.89, 3.9 , 3.68, 3.64, 3.76, 2.28, 2.09, 1.35,
#        1.01, 3.98, 3.93, 3.8 , 3.63, 3.51, 3.18, 3.4 , 3.36, 3.78, 2.68,
#        1.85, 1.88, 1.71, 1.61, 0.33, 2.39, 2.41, 2.24, 2.19, 1.74, 0.78,
#        3.2 , 3.26, 2.2 , 1.83, 1.78])

# %%
#Checking for number of  unique values present 
data['Mg'].nunique()
# Out:
# 93

# %% [markdown]
# * **There are about 93 unique values present in column Mg**

# %%
#Checking for unique values
data['Al'].unique()
# Out:
# array([1.36, 1.54, 1.29, 1.24, 1.62, 1.14, 1.05, 1.37, 1.56, 1.27, 1.4 ,
#        1.31, 1.23, 1.16, 0.89, 1.18, 1.69, 1.49, 0.29, 1.35, 1.15, 1.21,
#        1.41, 1.33, 1.43, 1.28, 1.3 , 1.38, 1.34, 1.32, 0.47, 1.12, 1.2 ,
#        0.72, 1.19, 0.71, 0.79, 0.51, 1.17, 1.11, 0.88, 0.78, 0.9 , 0.87,
#        0.82, 1.74, 1.52, 1.57, 1.51, 1.25, 1.9 , 2.12, 1.55, 2.08, 1.47,
#        1.48, 1.87, 1.45, 1.58, 1.06, 1.71, 1.44, 1.63, 0.83, 0.66, 1.88,
#        2.1 , 1.  , 0.56, 0.77, 0.75, 0.67, 1.26, 1.81, 1.53, 1.67, 1.08,
#        1.64, 1.61, 1.07, 1.79, 1.76, 0.65, 1.22, 0.58, 0.91, 3.5 , 1.86,
#        1.65, 1.83, 3.04, 3.02, 2.17, 1.66, 2.09, 0.34, 2.22, 2.06, 2.38,
#        2.79, 2.  , 1.98, 2.68, 2.54, 2.34, 2.66, 2.51, 2.25, 2.42, 1.99,
#        2.27, 1.8 , 1.82, 2.74, 2.88, 2.02, 1.94])

# %%
#Checking for number of  unique values present 
data['Al'].nunique()
# Out:
# 117

# %% [markdown]
# * **There are about 117 unique values present in Al column.**

# %%
#Checking for unique values
data['Si'].unique()
# Out:
# array([72.73, 72.99, 72.61, 73.08, 72.97, 73.09, 73.24, 72.08, 73.2 ,
#        73.01, 73.28, 73.21, 73.29, 73.11, 71.36, 72.12, 72.75, 72.02,
#        72.79, 73.02, 72.85, 73.  , 72.64, 73.04, 73.15, 72.86, 73.27,
#        73.39, 72.95, 72.74, 71.81, 72.96, 71.77, 73.03, 72.76, 71.76,
#        71.95, 72.72, 71.57, 71.99, 71.75, 72.36, 72.84, 72.98, 73.7 ,
#        71.72, 71.79, 71.35, 72.01, 71.96, 72.22, 72.32, 72.2 , 71.87,
#        73.1 , 72.87, 73.12, 72.39, 72.83, 72.88, 72.66, 73.17, 72.81,
#        72.28, 73.25, 72.65, 72.89, 73.23, 73.06, 73.26, 72.26, 72.34,
#        73.55, 72.92, 73.81, 70.57, 71.15, 72.19, 69.81, 70.16, 72.67,
#        74.45, 72.55, 72.44, 72.38, 72.33, 72.06, 72.53, 72.45, 72.4 ,
#        72.52, 72.51, 72.18, 71.24, 72.49, 72.78, 73.07, 73.36, 73.14,
#        72.54, 72.57, 72.77, 72.7 , 72.48, 71.5 , 72.69, 72.04, 71.94,
#        72.14, 69.89, 73.44, 73.75, 73.88, 70.48, 70.7 , 72.25, 72.37,
# ...

# %%
#Checking for number of  unique values present 
data['Si'].nunique()
# Out:
# 132

# %% [markdown]
# * **There are about 132 unique values present in Si column**

# %%
#Checking for unique values
data['K'].unique()
# Out:
# array([0.48, 0.39, 0.57, 0.55, 0.64, 0.58, 0.56, 0.67, 0.6 , 0.69, 0.54,
#        0.61, 0.15, 0.06, 0.03, 0.59, 0.62, 0.5 , 0.65, 0.51, 0.11, 0.17,
#        0.02, 0.13, 0.09, 0.14, 0.12, 0.23, 0.  , 0.18, 0.19, 0.16, 0.72,
#        0.66, 0.37, 0.68, 1.1 , 0.45, 0.38, 0.63, 0.44, 0.07, 0.73, 0.7 ,
#        0.35, 0.08, 0.81, 0.1 , 0.49, 0.53, 0.33, 0.52, 1.68, 0.47, 0.97,
#        0.32, 6.21, 0.76, 1.76, 1.46, 0.31, 0.04, 0.05, 2.7 , 1.41])

# %%
#Checking for number of  unique values present 
data['K'].nunique()
# Out:
# 65

# %% [markdown]
# * **There are about 65 unique values present in K column**

# %%
#Checking for unique values
data['Ca'].unique()
# Out:
# array([ 7.83,  7.78,  8.22,  8.07,  8.17,  8.24,  8.3 ,  8.4 ,  8.09,
#         8.56,  8.05,  8.38,  8.5 ,  8.39,  8.7 ,  9.15,  8.89,  8.44,
#         8.52,  9.  ,  8.59,  8.43,  8.53,  8.54,  8.49,  8.69,  8.55,
#         8.75,  8.57,  8.78,  8.68,  9.57,  8.77,  8.64,  9.74,  8.76,
#         8.83,  9.82, 10.02,  8.91, 10.06,  9.14,  9.03,  9.07,  9.02,
#         9.06,  8.35,  8.03,  8.27,  8.67,  9.54,  9.69,  9.61,  9.4 ,
#         9.85, 10.17,  7.36,  8.32,  7.89,  7.9 ,  7.96,  8.04,  7.94,
#         7.97,  7.86,  8.1 ,  7.08,  8.21,  8.08,  8.12,  8.96,  8.6 ,
#         9.13,  8.9 ,  8.79,  9.23,  9.42, 11.64, 10.79, 13.24, 13.3 ,
#        16.19, 11.52, 10.99, 14.68, 14.96, 14.4 ,  8.28,  8.31,  7.88,
#         8.42,  7.99, 10.56, 11.14, 13.44,  8.15,  8.11,  8.41,  8.23,
#         8.18,  8.81,  8.33,  9.49,  8.93,  8.58,  8.65,  9.65,  8.99,
#         5.87, 10.09, 11.41, 11.62, 11.53, 11.32, 12.24,  6.96,  6.93,
# ...

# %%
#Checking for number of  unique values present 
data['Ca'].nunique()
# Out:
# 143

# %% [markdown]
# * **There are about 143 unique values present in Ca column**

# %%
#Checking for unique values
data['Ba'].unique()
# Out:
# array([0.  , 0.09, 0.11, 0.69, 0.14, 3.15, 0.27, 0.06, 0.15, 2.2 , 0.24,
#        1.19, 1.63, 1.68, 0.76, 0.64, 0.4 , 1.59, 1.57, 0.61, 0.81, 0.66,
#        0.53, 0.63, 0.56, 1.71, 0.67, 1.55, 1.38, 2.88, 0.54, 1.06, 1.64,
#        1.67])

# %%
#Checking for number of  unique values present 
data['Ba'].nunique()
# Out:
# 34

# %% [markdown]
# * **There are about 34 unique values present in Ba column**

# %%
#Checking for unique values
data['Fe'].unique()
# Out:
# array([0.  , 0.26, 0.11, 0.24, 0.17, 0.07, 0.19, 0.14, 0.22, 0.06, 0.3 ,
#        0.16, 0.1 , 0.09, 0.31, 0.03, 0.12, 0.32, 0.15, 0.2 , 0.34, 0.28,
#        0.08, 0.29, 0.21, 0.18, 0.25, 0.35, 0.37, 0.51, 0.05, 0.01])

# %%
#Checking for number of  unique values present 
data['Fe'].nunique()
# Out:
# 32

# %% [markdown]
# * **There are about 32 unique values present in Fe column**

# %%
#Checking for unique values
data['type_of_glass'].unique()
# Out:
# array([1, 2, 3, 5, 6, 7], dtype=int64)

# %%
#Checking for number of  unique values present 
data['type_of_glass'].nunique()
# Out:
# 6

# %% [markdown]
# * **There are about 6 unique values present in Type of glass column**

# %% [markdown]
# * **So it is given that the dataset can be divided into window glass (classes 1-4) and non-window glass (classes 5-7).So replacing the the values to window glass and non-window glass**

# %%
#Replacing the 1,2,3 to window glass and 5,6,7 to non window glass
data['type_of_glass']=data['type_of_glass'].replace({1:'Window glass',2:'Window glass',3:'Window glass',5:'non-window glass',6:'non-window glass',7:'non-window glass'})

# %%
#Checking for unique values
data['type_of_glass'].unique()
# Out:
# array(['Window glass', 'non-window glass'], dtype=object)

# %% [markdown]
# * **So we can see that the classes 1-4 have been repalced by window glass and 5-7 by non_window glass**

# %%
df=data.drop(['type_of_glass'],axis=1)

# %%
df
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba    Fe
# 0    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.00
# 1    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.00
# 2    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.00
# 3    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.00
# 4    1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00  0.26
# ..       ...    ...   ...   ...    ...   ...   ...   ...   ...
# 208  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.00
# 209  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.00
# 210  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.00
# 211  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.00
# 212  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.00
#
# [212 rows x 9 columns]

# %%
#Plotting distribution plots
plt.figure(figsize=(20,20),facecolor='red')
plotnumber=1
for column in df:
    if plotnumber<=10:
        ax=plt.subplot(3,3,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# * **By looking at the plots we can see that data is not distributed normally in any of the plots and in every plots there are skewness. So further i will check for the skewness and i will treat it either by using log transformer or by using power transformer.**

# %%
#Plotting Scatter plot
sns.scatterplot(x='RI',y='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **By looking at the plot we can say that tha data is not balanced and when RI composition is more than 1.525 than it seems that it is mostly classified as window glass and if it less than 1.525 than it can be classified as both either widow or non window glass based on the other chemical properties, so depending on one value or two values we really cant decide or classify whether it is window glass or non window glass**

# %%
#Plotting Scatter plot
sns.scatterplot(x='Na',y='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot also we can see that data is not balanced and the when the Na composition is more than 15 than it is classified as non-window glass and if it less than it is classified as as either window or non-window depending on other chemical properties, basically in this the data is scattered, so depending on one value or two values we really cant decide or classify whether it is window glass or non window glass**

# %%
#Plotting Scatter plot
sns.scatterplot(x='Mg',y='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot also we can see that data is not balanced and the when the Mg composition is more than 3.5 than it is classified as window glass and if it less than it is classified as as either window or non-window depending on other chemical properties, basically in this the data is scattered, so depending on value or twi values we really cant decide or classify whether it is window glass or non window glass**

# %%
#Plotting Scatter plot
sns.scatterplot(x='Al',y='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot also we can see that data is not balanced and the when the Al composition is more than 2.5 than it is classified as non-window glass and if it less than it is classified as as either window or non-window depending on other chemical properties, basically in this the data is scattered, so depending on one value or two values we really cant decide or classify whether it is window glass or non window glass**

# %%
#Plotting Scatter plot
sns.scatterplot(x='Si',y='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot also we can see that data is not balanced and the when the Si composition is more than 75 than it is classified as non-window glass and if it less than it is classified as as either window or non-window depending on other chemical properties, basically in this the data is scattered, so depending on one value or two values we really cant decide or classify whether it is window glass or non window glass**

# %%
#Plotting Scatter plot
sns.scatterplot(x='K',y='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot also we can see that data is not balanced and the when the K composition is more than 1.5 than it is classified as non-window glass and if it less than it is classified as as either window or non-window depending on other chemical properties, basically in this the data is scattered, so depending on one value or two values we really cant decide or classify whether it is window glass or non window glass**

# %%
#Plotting Scatter plot
sns.scatterplot(x='Ca',y='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot also we can see that data is not balanced and the when the Ca composition is more than 12 than it is classified as window glass and if it less than it is classified as as either window or non-window depending on other chemical properties, basically in this the data is scattered, so depending on one value or two values we really cant decide or classify whether it is window glass or non window glass**

# %%
#Plotting Scatter plot
sns.scatterplot(x='Ba',y='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot also we can see that data is not balanced and the when the Ba composition is more than 0.7 and less than 3.0 it is classified as non-window glass and if it less than it is classified as as either window or non-window depending on other chemical properties,basically in this the data is scattered, so depending on one value or two values we really cant decide or classify whether it is window glass or non window glass**

# %%
#Plotting Scatter plot
sns.scatterplot(x='Fe',y='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot also we can see that data is not balanced and the when the Fe composition is more than 0.4 than it is classified as non-window glass and if it less than it is classified as as either window or non-window depending on other chemical properties basically in this the data is scattered, so depending on one value or two values we really cant decide or classify whether it is window glass or non window glass.**

# %%
#Plotting barplot plot
sns.barplot(x='type_of_glass',y='RI',data=data)
plt.show()

# %% [markdown]
# * **In this plow we can see that RI composition is same for the window class and non-window glass**

# %%
#Plotting barplot plot
sns.barplot(x='type_of_glass',y='Na',data=data)
plt.show()

# %% [markdown]
# * **From this plot we can observe that composition of Na is little bit more in non-window glass as compared to window glass.**

# %%
#Plotting barplot plot
sns.barplot(x='type_of_glass',y='Mg',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that Mg compostion is more in window glass compared to non-window glass**

# %%
#Plotting barplot plot
sns.barplot(x='type_of_glass',y='Al',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that Al compostion is more in non-window glass compared to window glass**

# %%
#Plotting barplot plot
sns.barplot(x='type_of_glass',y='Si',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that Si compostion is more over equal in non-window glass as well as window glass**

# %%
#Plotting barplot plot
sns.barplot(x='type_of_glass',y='K',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that K compostion is more in non-window glass compared to window glass**

# %%
#Plotting barplot plot
sns.barplot(x='type_of_glass',y='Ca',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that Ca compostion is more over equal in non-window glass as well as window glass**

# %%
#Plotting barplot plot
sns.barplot(x='type_of_glass',y='Ba',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that Ba compostion is more in non-window glass compared to window glass**

# %%
#Plotting barplot plot
sns.barplot(x='type_of_glass',y='Fe',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that Fe compostion is more in window glass compared to non-window glass**

# %%
#Plotting Scatter plot
sns.scatterplot(x='RI',y='Na',hue='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that if RI and Na compositon is there its more likely to classify glass as Window glass over non-window glass as we can see more percentage of window glass than non-window glass. still its not accurate, always there are other ways to classify.**

# %%
#Plotting Scatter plot
sns.scatterplot(x='RI',y='Mg',hue='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that if RI and Mg compositon is there its more likely to classify glass as Window glass over non-window glass as we can see more percentage of window glass than non-window glass. still its not accurate, always there are other ways to classify.**

# %%
#Plotting Scatter plot
sns.scatterplot(x='RI',y='Al',hue='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that if RI and Al compositon is there its more likely to classify glass as Window glass over non-window glass as we can see more percentage of window glass than non-window glass. still its not accurate, always there are other ways to classify.**

# %%
#Plotting Scatter plot
sns.scatterplot(x='RI',y='Si',hue='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that if RI and Si compositon is there its more likely to classify glass as Window glass over non-window glass as we can see more percentage of window glass than non-window glass. still its not accurate, always there are other ways to classify.**

# %%
#Plotting Scatter plot
sns.scatterplot(x='RI',y='K',hue='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that if RI and K compositon is there its more likely to classify glass as Window glass over non-window glass as we can see more percentage of window glass than non-window glass. still its not accurate, always there are other ways to classify.**

# %%
#Plotting Scatter plot
sns.scatterplot(x='RI',y='Ca',hue='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that if RI and Ca compositon is there its more likely to classify glass as Window glass over non-window glass as we can see more percentage of window glass than non-window glass. still its not accurate, always there are other ways to classify.**

# %%
#Plotting Scatter plot
sns.scatterplot(x='RI',y='Ba',hue='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that if RI and Ba compositon is there its more likely to classify glass as Non-Window glass over window glass as we can see more percentage of non-window glass than window glass. still its not accurate, always there are other ways to classify.**

# %%
#Plotting Scatter plot
sns.scatterplot(x='RI',y='Fe',hue='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that if RI and Fe compositon is there its more likely to classify glass as Window glass over non-window glass as we can see more percentage of window glass than non-window glass. still its not accurate, always there are other ways to classify.**

# %%
#Plotting Scatter plot
sns.scatterplot(x='Na',y='Mg',hue='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that if Na and Mg compositon is there its more likely to classify glass as Window glass over non-window glass as we can see more percentage of window glass than non-window glass. still its not accurate, always there are other ways to classify.**

# %%
#Plotting Scatter plot
sns.scatterplot(x='Na',y='Al',hue='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that if Na and Al compositon is there its more likely to classify glass as Window glass over non-window glass as we can see more percentage of window glass than non-window glass. still its not accurate, always there are other ways to classify.**

# %%
#Plotting Scatter plot
sns.scatterplot(x='Na',y='Si',hue='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that if Na and Si compositon is there its more likely to classify glass as Window glass over non-window glass as we can see more percentage of window glass than non-window glass. still its not accurate, always there are other ways to classify.**

# %%
#Plotting Scatter plot
sns.scatterplot(x='Na',y='K',hue='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that if Na and K compositon is there its more likely to classify glass as Window glass over non-window glass as we can see more percentage of window glass than non-window glass. still its not accurate, always there are other ways to classify.**

# %%
#Plotting Scatter plot
sns.scatterplot(x='Na',y='Ca',hue='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that if Na and Ca compositon is there its more likely to classify glass as Window glass over non-window glass as we can see more percentage of window glass than non-window glass. still its not accurate, always there are other ways to classify.**

# %%
#Plotting Scatter plot
sns.scatterplot(x='Na',y='Ba',hue='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that if Na and Ba compositon is there its more likely to classify glass as non-Window glass over window glass as we can see more percentage of non-window glass than window glass. still its not accurate, always there are other ways to classify.**

# %%
#Plotting Scatter plot
sns.scatterplot(x='Na',y='Fe',hue='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that if Na and Fe compositon is there its more likely to classify glass as Window glass over non-window glass as we can see more percentage of window glass than non-window glass. still its not accurate, always there are other ways to classify.**

# %%
#Plotting Scatter plot
sns.scatterplot(x='Mg',y='Al',hue='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that if Mg and Al compositon is there its more likely to classify glass as Window glass over non-window glass as we can see more percentage of window glass than non-window glass. still its not accurate, always there are other ways to classify.**

# %%
#Plotting Scatter plot
sns.scatterplot(x='Mg',y='Si',hue='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that if Mg and Si compositon is there its more likely to classify glass as Window glass over non-window glass as we can see more percentage of window glass than non-window glass. still its not accurate, always there are other ways to classify.**

# %%
#Plotting Scatter plot
sns.scatterplot(x='Mg',y='K',hue='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that if Mg and K compositon is there its more likely to classify glass as Window glass over non-window glass as we can see more percentage of window glass than non-window glass. still its not accurate, always there are other ways to classify.**

# %%
#Plotting Scatter plot
sns.scatterplot(x='Mg',y='Ca',hue='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that if Mg and Ca compositon is there its more likely to classify glass as Window glass over non-window glass as we can see more percentage of window glass than non-window glass. still its not accurate, always there are other ways to classify.**

# %%
#Plotting Scatter plot
sns.scatterplot(x='Mg',y='Ba',hue='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that if Mg and Ba compositon is there its more likely to classify glass either as Window glass or non-window glass as we can see more percentage of window glass and non-window glass is same in the plot. still its not accurate, always there are other ways to classify.**

# %%
#Plotting Scatter plot
sns.scatterplot(x='Mg',y='Fe',hue='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that if Mg and Fe compositon is there its more likely to classify glass as Window glass over non-window glass as we can see more percentage of window glass than non-window glass. still its not accurate, always there are other ways to classify.**

# %%
#Plotting Scatter plot
sns.scatterplot(x='Al',y='Si',hue='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that if Al and Si compositon is there its more likely to classify glass as Window glass over non-window glass as we can see more percentage of window glass than non-window glass. still its not accurate, always there are other ways to classify.**

# %%
#Plotting Scatter plot
sns.scatterplot(x='Al',y='K',hue='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that if Al and K compositon is there its more likely to classify glass as Window glass over non-window glass as we can see more percentage of window glass than non-window glass. still its not accurate, always there are other ways to classify.**

# %%
#Plotting Scatter plot
sns.scatterplot(x='Al',y='Ca',hue='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that if Al and Ca compositon is there its more likely to classify glass as Window glass over non-window glass as we can see more percentage of window glass than non-window glass. still its not accurate, always there are other ways to classify.**

# %%
#Plotting Scatter plot
sns.scatterplot(x='Al',y='Ba',hue='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that if Al and Ba compositon is there its more likely to classify glass either as Window glass or non-window glass as we can see more percentage of window glass and non-window glass is same in the plot. still its not accurate, always there are other ways to classify.**

# %%
#Plotting Scatter plot
sns.scatterplot(x='Al',y='Fe',hue='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that if Al and Fe compositon is there its more likely to classify glass as Window glass over non-window glass as we can see more percentage of window glass than non-window glass. still its not accurate, always there are other ways to classify.**

# %%
#Plotting Scatter plot
sns.scatterplot(x='Si',y='K',hue='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that if Si and K compositon is there its more likely to classify glass as Window glass over non-window glass as we can see more percentage of window glass than non-window glass. still its not accurate, always there are other ways to classify.**

# %%
#Plotting Scatter plot
sns.scatterplot(x='Si',y='Ca',hue='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that if Si and Ca compositon is there its more likely to classify glass as Window glass over non-window glass as we can see more percentage of window glass than non-window glass. still its not accurate, always there are other ways to classify.**

# %%
#Plotting Scatter plot
sns.scatterplot(x='Si',y='Ba',hue='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that if Si and Ba compositon is there its more likely to classify glass either as Window glass or non-window glass as we can see more percentage of window glass and non-window glass is same in the plot. still its not accurate, always there are other ways to classify.**

# %%
#Plotting Scatter plot
sns.scatterplot(x='Si',y='Fe',hue='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that if Si and Fe compositon is there its more likely to classify glass as Window glass over non-window glass as we can see more percentage of window glass than non-window glass. still its not accurate, always there are other ways to classify.**

# %%
#Plotting Scatter plot
sns.scatterplot(x='K',y='Ca',hue='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that if K and Ca compositon is there its more likely to classify glass as Window glass over non-window glass as we can see more percentage of window glass than non-window glass. still its not accurate, always there are other ways to classify.**

# %%
#Plotting Scatter plot
sns.scatterplot(x='K',y='Ba',hue='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that if K and Ba compositon is there its more likely to classify glass as non-Window glass over window glass as we can see more percentage of non-window glass than window glass. still its not accurate, always there are other ways to classify.**

# %%
#Plotting Scatter plot
sns.scatterplot(x='K',y='Fe',hue='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that if K and Fe compositon is there its more likely to classify glass as Window glass over non-window glass as we can see more percentage of window glass than non-window glass. still its not accurate, always there are other ways to classify.**

# %%
#Plotting Scatter plot
sns.scatterplot(x='Ca',y='Ba',hue='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that if Ca and Ba compositon is there its more likely to classify glass as non-Window glass over window glass as we can see more percentage of non-window glass than window glass. still its not accurate, always there are other ways to classify.**

# %%
#Plotting Scatter plot
sns.scatterplot(x='Ca',y='Fe',hue='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that if Ca and Fe compositon is there its more likely to classify glass as Window glass over non-window glass as we can see more percentage of window glass than non-window glass. still its not accurate, always there are other ways to classify.**

# %%
#Plotting Scatter plot
sns.scatterplot(x='Ba',y='Fe',hue='type_of_glass',data=data)
plt.show()

# %% [markdown]
# * **In this plot we can see that if Ba and Fe compositon is there its more likely to classify glass as either Window glass or non-window glass as we can see equal amout percentage of window glass as well as non-window glass. still its not accurate, always there are other ways to classify.**

# %%
#Since column type of glass have categorical values so using label encoder to encode
#Importing required libraries
from sklearn.preprocessing import LabelEncoder

# %%
#Encoding column Sex, smoker and region
lab_enc=LabelEncoder()
df=lab_enc.fit_transform(data['type_of_glass'])

# %%
#Transfering data to column type of glass
data['type_of_glass']=df

# %%
#Checking whether the data is encoded or not
data.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba    Fe  type_of_glass
# 0  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.00              0
# 1  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.00              0
# 2  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.00              0
# 3  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.00              0
# 4  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.0  0.26              0

# %% [markdown]
# * **As we can see that the data has been encoded**

# %%
#Checking correlation
data.corr()
# Out:
#                      RI        Na        Mg        Al        Si         K  \
# RI             1.000000 -0.200410 -0.133485 -0.399241 -0.536903 -0.285677
# Na            -0.200410  1.000000 -0.281243  0.168932 -0.063542 -0.263572
# Mg            -0.133485 -0.281243  1.000000 -0.477731 -0.156776  0.011667
# Al            -0.399241  0.168932 -0.477731  1.000000 -0.020055  0.322163
# Si            -0.536903 -0.063542 -0.156776 -0.020055  1.000000 -0.201708
# K             -0.285677 -0.263572  0.011667  0.322163 -0.201708  1.000000
# Ca             0.813304 -0.278066 -0.447038 -0.258863 -0.208554 -0.317844
# Ba             0.003154  0.329726 -0.491701  0.480171 -0.106636 -0.044838
# Fe             0.149921 -0.238812  0.089321 -0.082708 -0.101251 -0.011262
# type_of_glass -0.129642  0.457493 -0.757945  0.585768  0.143171  0.050603
#
#                      Ca        Ba        Fe  type_of_glass
# RI             0.813304  0.003154  0.149921      -0.129642
# ...

# %%
#Plotting correlation
data.drop(['type_of_glass'],axis=1).corrwith(data['type_of_glass']).plot(kind='bar',grid=True,figsize=(10,5),title='Correlation with type_of_glass')
plt.show()

# %% [markdown]
# * **In this we can see that Mg is more negatively correlated label followed by Al,Ba and Na. And K and Ca is very least correlated with the label**

# %%
#Plotting Heatmap
corr=data.corr().abs()
plt.figure(figsize=(10,5))
sns.heatmap(corr,annot=True)
plt.show()

# %% [markdown]
# * **In this i can see that there is multicollinearity between RI and CA, so i will plot scatterplot and if i find any positive trend between them i will take further steps.**

# %%
#Plotting scatter plot
sns.scatterplot(x='RI',y='Ca',data=data)
plt.show()

# %% [markdown]
# * **By looking at the plot i can see that there is positive relationship or trend between them.So i will have to drop Ca column as it is least correlated with the label as compared to RI.**

# %%
#Checking Skewness
data.skew()
# Out:
# RI               1.662549
# Na               0.468899
# Mg              -1.147886
# Al               0.931156
# Si              -0.758957
# K                6.543138
# Ca               2.044273
# Ba               3.397046
# Fe               1.739994
# type_of_glass    1.222600
# dtype: float64

# %% [markdown]
# * **In this we can see that except type of glass which is a label, as we dont treat skewness of the label,in every column there is skewness.**

# %%
#Transforming the data of features using power transform method to remove skewness
#Importing required libraries
from sklearn.preprocessing import power_transform

# %%
data[['RI','Na','Mg','Al','Si','K','Ca','Ba','Fe']]=power_transform(data[['RI','Na','Mg','Al','Si','K','Ca','Ba','Fe']],method='yeo-johnson')
data[['RI','Na','Mg','Al','Si','K','Ca','Ba','Fe']]
# Out:
#                RI        Na        Mg        Al        Si         K        Ca  \
# 0   -1.387779e-17  0.622137  0.685637 -0.089851  0.032086  0.262872 -0.878270
# 1   -4.510281e-17  0.190226  0.624963  0.282469  0.388875  0.006118 -0.931827
# 2   -1.040834e-17 -0.204873  0.796938 -0.242612 -0.127600  0.490578 -0.483956
# 3   -1.734723e-17 -0.129964  0.710139 -0.354704  0.515904  0.442230 -0.630874
# 4   -5.204170e-17 -0.740341  0.697871  0.439295  0.360896  0.650636 -0.630874
# ..            ...       ...       ...       ...       ...       ...       ...
# 208 -4.510281e-17  0.914602 -1.735088  2.412174 -0.127600 -1.200279  0.336638
# 209 -3.122502e-17  1.790306 -1.735088  1.105677  0.487516 -1.631083 -0.314947
# 210  6.245005e-17  1.167108 -1.735088  1.155929  1.012711 -1.631083 -0.278422
# 211 -4.163336e-17  1.189843 -1.735088  1.020758  1.302355 -1.631083 -0.242262
# 212 -2.775558e-17  1.018441 -1.735088  1.254907  0.923059 -1.631083 -0.118494
#
#            Ba        Fe
# ...

# %%
#Checking Skewness
data.skew()
# Out:
# RI               0.000000
# Na              -0.010956
# Mg              -0.907541
# Al              -0.002188
# Si               0.137478
# K               -0.078107
# Ca              -0.209112
# Ba               1.810855
# Fe               0.846420
# type_of_glass    1.222600
# dtype: float64

# %%
#Plotting Boxplot
data['RI'].plot.box()
plt.show()

# %% [markdown]
# * **We can see a lot of outliers in RI**

# %%
#Plotting Boxplot
data['Na'].plot.box()
plt.show()

# %% [markdown]
# * **Outliers are there in Na**

# %%
#Plotting Boxplot
data['Mg'].plot.box()
plt.show()

# %% [markdown]
# * **Outliers are not there in Mg**

# %%
#Plotting Boxplot
data['Al'].plot.box()
plt.show()

# %% [markdown]
# * **We can see a lot of outliers in Al**

# %%
#Plotting Boxplot
data['Si'].plot.box()
plt.show()

# %% [markdown]
# * **We can see a lot of outliers in Si**

# %%
#Plotting Boxplot
data['K'].plot.box()
plt.show()

# %% [markdown]
# * **outliers are there in K**

# %%
#Plotting Boxplot
data['Ca'].plot.box()
plt.show()

# %% [markdown]
# * **We can see a lot of outliers in Ca**

# %%
#Plotting Boxplot
data['Ba'].plot.box()
plt.show()

# %% [markdown]
# * **We can see a lot of outliers in Ba**

# %%
#Plotting Boxplot
data['Fe'].plot.box()
plt.show()

# %% [markdown]
# * **Outliers are not there in Fe**

# %%
#using zscore method to remove outliers
from scipy.stats import zscore

# %%
#Removing outliers of RI,Na,Al,Si,K,Ca,Ba
z_score=zscore(data[['RI','Na','Al','Si','K','Ca','Ba']])
abs_z_score=np.abs(z_score)
threshold=3
z=(abs_z_score<3).all(axis=1)

# %%
data=data[z]

# %%
#checking rows and columns
data.shape
# Out:
# (199, 10)

# %%
#Percentage Loss of Data
data_loss=((212-199)/212)*100
print(f'Data Loss:{data_loss} %')
# Out:
# Data Loss:6.132075471698113 %

# %%
#Checking data of the label
data.type_of_glass.value_counts()
# Out:
# 0    156
# 1     43
# Name: type_of_glass, dtype: int64

# %% [markdown]
# * **So we can see that the data is imbalanced, So i am using over sampling-smote method.**

# %%
#Dividing dataset into features and label
#Features
x=data.drop(['type_of_glass','Ca'],axis=1)
#Label
y=data['type_of_glass']

# %% [markdown]
# **As i have mentioned above that there is multicollinearity between RI and Ca, as we had seen in the heatmap and so by plotting scatter plot it confirmed that there was an multicollinearity between the two as it was showing positive relationship.Further it noticed that RI is more correlated to label than Ca, thats why i am dropping Ca column.**

# %%
#Using oversampling method-Smote method
#importing required libraries
from imblearn.over_sampling import SMOTE

# %%
over_samp=SMOTE(0.75)

# %%
x_new,y_new=over_samp.fit_resample(x,y)

# %%
print('The number of classes before fit {}'.format(y.value_counts()))
# Out:
# The number of classes before fit 0    156
# 1     43
# Name: type_of_glass, dtype: int64

# %%
print('The number of classes after fit {}'.format(y_new.value_counts()))
# Out:
# The number of classes after fit 0    156
# 1    117
# Name: type_of_glass, dtype: int64

# %% [markdown]
# * **Now we can that the data is balanced**

# %% [markdown]
# * **I am not standardising the data because i have already used power transform method to remove skewness. So when we are using power transform method its not necessary to standardise the data.**

# %%
#Importing required libraries
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_curve,roc_auc_score,plot_roc_curve,f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# **Logistic Regression**

# %%
#Initiating Logistic Regression
lr=LogisticRegression()

# %%
#using range fucntion to find the best random state using Logestic regression
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(x_new,y_new,test_size=0.25,random_state=i)
    lr.fit(x_train,y_train)
    pred=lr.predict(x_train)
    y_pred=lr.predict(x_test)
    print(f'at random state{i},the training accuracy is:{accuracy_score(y_train,pred)*100}')
    print(f'at random state{i},the testing accuracy is:{accuracy_score(y_test,y_pred)*100}')
    print('\n')
# Out:
# at random state0,the training accuracy is:97.54901960784314
# at random state0,the testing accuracy is:97.10144927536231
#
#
# at random state1,the training accuracy is:98.52941176470588
# at random state1,the testing accuracy is:95.65217391304348
#
#
# at random state2,the training accuracy is:98.0392156862745
# at random state2,the testing accuracy is:97.10144927536231
#
#
# at random state3,the training accuracy is:97.54901960784314
# at random state3,the testing accuracy is:98.55072463768117
#
#
# at random state4,the training accuracy is:97.54901960784314
# at random state4,the testing accuracy is:95.65217391304348
#
#
# at random state5,the training accuracy is:98.0392156862745
# at random state5,the testing accuracy is:97.10144927536231
#
#
# at random state6,the training accuracy is:98.52941176470588
# at random state6,the testing accuracy is:95.65217391304348
#
#
# at random state7,the training accuracy is:96.56862745098039
# at random state7,the testing accuracy is:100.0
#
# ...

# %% [markdown]
# * **Taking the random state=28**

# %%
#Training Testing and Spliting the data
x_train,x_test,y_train,y_test=train_test_split(x_new,y_new,test_size=0.25,random_state=22)

# %%
#Building Model to test unexposed data
def metric_score(clf,x_train,x_test,y_train,y_test,train=True):
    if train:
        pred=clf.predict(x_train)
        print('\n=====Train Score=====')
        print(f'Accuracy Score:{accuracy_score(y_train,pred)*100:.2f}%')
    elif train==False:
        y_pred=clf.predict(x_test)
        print('\n=====Test Score=====')
        print(f'Accuracy Score:{accuracy_score(y_test,y_pred)*100:.2f}%')
        print('\n Test Classification Report:\n',classification_report(y_test,y_pred,digits=2))
        print('\n Confusion Matrix:\n',confusion_matrix(y_test,y_pred))
        print('\n F1 Score:\n',f1_score(y_test,y_pred))

# %%
#Training the data
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
#calling the function and passing the dataset for logistic regression
metric_score(lr,x_train,x_test,y_train,y_test,train=True)#for training
metric_score(lr,x_train,x_test,y_train,y_test,train=False)#for testing
# Out:
# =====Train Score=====
# Accuracy Score:98.53%
#
# =====Test Score=====
# Accuracy Score:97.10%
#
#  Test Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        37
#            1       0.97      0.97      0.97        32
#
#     accuracy                           0.97        69
#    macro avg       0.97      0.97      0.97        69
# weighted avg       0.97      0.97      0.97        69
#
#
#  Confusion Matrix:
#  [[36  1]
#  [ 1 31]]
#
#  F1 Score:
#  0.96875

# %%
#Checking Cross Validation score
#Importing required libraries
from sklearn.model_selection import cross_val_score

# %%
y_pred=lr.predict(x_test)
test_accuracy=accuracy_score(y_test,y_pred)

# %%
#Checking cross validation score
for j in range(2,6):
    cv_score=cross_val_score(lr,x_new,y_new,cv=j)
    cv_mean=cv_score.mean()
    print(f'at cross fold {j} the cv score is{cv_mean}and accuracy for the testing is {test_accuracy}')
    print('\n')
# Out:
# at cross fold 2 the cv score is0.9450139544869043and accuracy for the testing is 0.9710144927536232
#
#
# at cross fold 3 the cv score is0.9633699633699635and accuracy for the testing is 0.9710144927536232
#
#
# at cross fold 4 the cv score is0.9634484228473998and accuracy for the testing is 0.9710144927536232
#
#
# at cross fold 5 the cv score is0.9484848484848485and accuracy for the testing is 0.9710144927536232

# %%
#plotting roc curve
fpr,tpr,threshold=roc_curve(y_test,y_pred)

# %%
print('FPR',fpr)
print('TPR',tpr)
print('Threshold',threshold)
# Out:
# FPR [0.         0.02702703 1.        ]
# TPR [0.      0.96875 1.     ]
# Threshold [2 1 0]

# %%
plt.plot(fpr,tpr,color='orange',label='ROC')
plt.plot([0,1],[0,1],color='blue',linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# %% [markdown]
# **KNEIGHNORS CLASSIFIER**

# %%
#Instantiating the models
knn=KNeighborsClassifier()

# %%
#Training Testing and Spliting the data
x_train,x_test,y_train,y_test=train_test_split(x_new,y_new,test_size=0.25,random_state=22)

# %%
#Training the data
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
#calling the function and passing the dataset for logistic regression
metric_score(knn,x_train,x_test,y_train,y_test,train=True)#for training
metric_score(knn,x_train,x_test,y_train,y_test,train=False)#for testing
# Out:
# =====Train Score=====
# Accuracy Score:98.04%
#
# =====Test Score=====
# Accuracy Score:94.20%
#
#  Test Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95        37
#            1       0.97      0.91      0.94        32
#
#     accuracy                           0.94        69
#    macro avg       0.94      0.94      0.94        69
# weighted avg       0.94      0.94      0.94        69
#
#
#  Confusion Matrix:
#  [[36  1]
#  [ 3 29]]
#
#  F1 Score:
#  0.9354838709677419

# %%
y_pred=knn.predict(x_test)
test_accuracy=accuracy_score(y_test,y_pred)

# %%
#Checking cross validation score
for j in range(2,6):
    cv_score=cross_val_score(knn,x_new,y_new,cv=j)
    cv_mean=cv_score.mean()
    print(f'at cross fold {j} the cv score is{cv_mean}and accuracy for the testing is {test_accuracy}')
    print('\n')
# Out:
# at cross fold 2 the cv score is0.9633426363246029and accuracy for the testing is 0.9420289855072463
#
#
# at cross fold 3 the cv score is0.9633699633699634and accuracy for the testing is 0.9420289855072463
#
#
# at cross fold 4 the cv score is0.9634484228473998and accuracy for the testing is 0.9420289855072463
#
#
# at cross fold 5 the cv score is0.9632323232323232and accuracy for the testing is 0.9420289855072463

# %%
#plotting roc curve
fpr,tpr,threshold=roc_curve(y_test,y_pred)

# %%
print('FPR',fpr)
print('TPR',tpr)
print('Threshold',threshold)
# Out:
# FPR [0.         0.02702703 1.        ]
# TPR [0.      0.90625 1.     ]
# Threshold [2 1 0]

# %%
plt.plot(fpr,tpr,color='orange',label='ROC')
plt.plot([0,1],[0,1],color='blue',linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# %% [markdown]
# **DECISIONTREE CLASSIFIER**

# %%
#Instantiating the models
dt=DecisionTreeClassifier()

# %%
#Training Testing and Spliting the data
x_train,x_test,y_train,y_test=train_test_split(x_new,y_new,test_size=0.25,random_state=22)

# %%
#Training the data
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
#calling the function and passing the dataset for logistic regression
metric_score(dt,x_train,x_test,y_train,y_test,train=True)#for training
metric_score(dt,x_train,x_test,y_train,y_test,train=False)#for testing
# Out:
# =====Train Score=====
# Accuracy Score:100.00%
#
# =====Test Score=====
# Accuracy Score:91.30%
#
#  Test Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.97      0.92        37
#            1       0.96      0.84      0.90        32
#
#     accuracy                           0.91        69
#    macro avg       0.92      0.91      0.91        69
# weighted avg       0.92      0.91      0.91        69
#
#
#  Confusion Matrix:
#  [[36  1]
#  [ 5 27]]
#
#  F1 Score:
#  0.8999999999999999

# %%
y_pred=dt.predict(x_test)
test_accuracy=accuracy_score(y_test,y_pred)

# %%
#Checking cross validation score
for j in range(2,6):
    cv_score=cross_val_score(dt,x_new,y_new,cv=j)
    cv_mean=cv_score.mean()
    print(f'at cross fold {j} the cv score is{cv_mean}and accuracy for the testing is {test_accuracy}')
    print('\n')
# Out:
# at cross fold 2 the cv score is0.94131064834693and accuracy for the testing is 0.9130434782608695
#
#
# at cross fold 3 the cv score is0.9377289377289376and accuracy for the testing is 0.9130434782608695
#
#
# at cross fold 4 the cv score is0.9340366581415175and accuracy for the testing is 0.9130434782608695
#
#
# at cross fold 5 the cv score is0.9410774410774412and accuracy for the testing is 0.9130434782608695

# %%
#plotting roc curve
fpr,tpr,threshold=roc_curve(y_test,y_pred)

# %%
print('FPR',fpr)
print('TPR',tpr)
print('Threshold',threshold)
# Out:
# FPR [0.         0.02702703 1.        ]
# TPR [0.      0.84375 1.     ]
# Threshold [2 1 0]

# %%
plt.plot(fpr,tpr,color='orange',label='ROC')
plt.plot([0,1],[0,1],color='blue',linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# %% [markdown]
# **RandomForest Classifier**

# %%
#Instantiating the models
rfc=RandomForestClassifier()

# %%
#Training Testing and Spliting the data
x_train,x_test,y_train,y_test=train_test_split(x_new,y_new,test_size=0.25,random_state=22)

# %%
#Training the data
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
#calling the function and passing the dataset for logistic regression
metric_score(rfc,x_train,x_test,y_train,y_test,train=True)#for training
metric_score(rfc,x_train,x_test,y_train,y_test,train=False)#for testing
# Out:
# =====Train Score=====
# Accuracy Score:100.00%
#
# =====Test Score=====
# Accuracy Score:97.10%
#
#  Test Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        37
#            1       0.97      0.97      0.97        32
#
#     accuracy                           0.97        69
#    macro avg       0.97      0.97      0.97        69
# weighted avg       0.97      0.97      0.97        69
#
#
#  Confusion Matrix:
#  [[36  1]
#  [ 1 31]]
#
#  F1 Score:
#  0.96875

# %%
y_pred=rfc.predict(x_test)
test_accuracy=accuracy_score(y_test,y_pred)

# %%
#Checking cross validation score
for j in range(2,6):
    cv_score=cross_val_score(rfc,x_new,y_new,cv=j)
    cv_mean=cv_score.mean()
    print(f'at cross fold {j} the cv score is{cv_mean}and accuracy for the testing is {test_accuracy}')
    print('\n')
# Out:
# at cross fold 2 the cv score is0.9413643194504079and accuracy for the testing is 0.9710144927536232
#
#
# at cross fold 3 the cv score is0.9560439560439561and accuracy for the testing is 0.9710144927536232
#
#
# at cross fold 4 the cv score is0.9596653878942882and accuracy for the testing is 0.9710144927536232
#
#
# at cross fold 5 the cv score is0.9593939393939394and accuracy for the testing is 0.9710144927536232

# %%
#plotting roc curve
fpr,tpr,threshold=roc_curve(y_test,y_pred)

# %%
print('FPR',fpr)
print('TPR',tpr)
print('Threshold',threshold)
# Out:
# FPR [0.         0.02702703 1.        ]
# TPR [0.      0.96875 1.     ]
# Threshold [2 1 0]

# %%
plt.plot(fpr,tpr,color='orange',label='ROC')
plt.plot([0,1],[0,1],color='blue',linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# %%
#Making dataframe of all the models
data=pd.DataFrame({
    'Models':['Logistic','KNN','Decision Tree','Random Forest'],
    'Training Score':[98.53,98.04,100,100],
    'Testing Score':[97.10,94.20,91.30,97.10],
    'Cross Val Score':[94.84,96.33,93.40,95.96],
    'F1 score':[96.87,93.54,89.99,96.87]
})
data
# Out:
#           Models  Training Score  Testing Score  Cross Val Score  F1 score
# 0       Logistic           98.53           97.1            94.84     96.87
# 1            KNN           98.04           94.2            96.33     93.54
# 2  Decision Tree          100.00           91.3            93.40     89.99
# 3  Random Forest          100.00           97.1            95.96     96.87

# %% [markdown]
# **Observation**
# * **I am going for random forest because the cross validation score and test accuracy score is very close as compared to other models and it has seen most of the data as compared to other models.**
# * **The confusion matrix of logistic regression has only 1 False positive and 1 False negative and Random forest also have 1 False positive and 1 False Negative which is same.**
# * **The F1 score is of logistic regression is 96% and and random forest is also 96% which is again same.**
# * **But the cross validation score of random forest is 95% and testing score w is 97% and for logistic regrression testing score is 97% and cross validation score is 94% and plus the Random forest has seen all of the data.**
# * **So considering each every aspect of F1 score, confusion matrix test accuracy and cross validation score. I am going forward with Random Forest Classifier**

# %%
#Using Grid Search cv for hyperparameter tuning for RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# %%
param_grid=({
    'n_estimators': [200, 500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [4,5,6,7,8],
    'criterion' :['gini', 'entropy']
})

# %%
grid_search=GridSearchCV(rfc,param_grid=param_grid,cv=5)

# %%
#Training
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [4, 5, 6, 7, 8],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [200, 500]})

# %%
#best Parameters
grid_search.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 5,
#  'max_features': 'auto',
#  'n_estimators': 500}

# %%
#Training with the best parameters
rfc=RandomForestClassifier(criterion='entropy',max_depth=7,max_features='auto',n_estimators=500)
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=7, max_features='auto',
#                        n_estimators=500)

# %%
#calling the function and passing the dataset
metric_score(rfc,x_train,x_test,y_train,y_test,train=True)#Training Score
metric_score(rfc,x_train,x_test,y_train,y_test,train=False)#Testing Score
# Out:
# =====Train Score=====
# Accuracy Score:100.00%
#
# =====Test Score=====
# Accuracy Score:97.10%
#
#  Test Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        37
#            1       0.97      0.97      0.97        32
#
#     accuracy                           0.97        69
#    macro avg       0.97      0.97      0.97        69
# weighted avg       0.97      0.97      0.97        69
#
#
#  Confusion Matrix:
#  [[36  1]
#  [ 1 31]]
#
#  F1 Score:
#  0.96875

# %%
#Checking cross validation score
cv_score=cross_val_score(rfc,x_new,y_new,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.9593939393939394

# %%
#plotting roc curve
fpr,tpr,threshold=roc_curve(y_test,y_pred)

# %%
print('FPR',fpr)
print('TPR',tpr)
print('Threshold',threshold)
# Out:
# FPR [0.         0.02702703 1.        ]
# TPR [0.      0.96875 1.     ]
# Threshold [2 1 0]

# %%
plt.plot(fpr,tpr,color='orange',label='ROC')
plt.plot([0,1],[0,1],color='blue',linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# %%
#Checking AUC Score
roc_auc_score=roc_auc_score(y_test,y_pred)
roc_auc_score
# Out:
# 0.9708614864864865

# %%
#saving the model
#Importing required libraries
import pickle
pickle.dump(rfc,open('Glass Project','wb'))
