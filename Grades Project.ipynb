# %% [markdown]
# **Problem Statement:**
# The dataset contains grades scored by students throughout their university tenure in various courses and their CGPA calculated based on their grades

# %%
#Importing required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#Loading Dataset
data=pd.read_csv('grades.csv')

# %%
#Checking overview of the dataset
data.head()
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 0  ...     C-     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1  ...     D+      D      C      D     A-     B-      C      C      B  2.008
# 2  ...      B      B      A      C      A      A      A     A-      A  3.608
# 3  ...     D+      C     D+     C-     B-      B     C+     C+     C+  1.906
# 4  ...     B-     B+     B+     B-     A-      A     A-     A-      A  3.448
#
# [5 rows x 43 columns]

# %%
#Checking shape of the dataset
data.shape
# Out:
# (571, 43)

# %% [markdown]
# **So there 571 rows and 43 columns in the dataset**

# %%
#Checking for the null values
data.isna().sum()
# Out:
# Seat No.      0
# PH-121        0
# HS-101        0
# CY-105        1
# HS-105/12     1
# MT-111        2
# CS-105        0
# CS-106        2
# EL-102        2
# EE-119        2
# ME-107        2
# CS-107        2
# HS-205/20     5
# MT-222        5
# EE-222        7
# MT-224        7
# CS-210        7
# CS-211        5
# CS-203        5
# CS-214        6
# EE-217        6
# CS-212        6
# CS-215        6
# MT-331        9
# EF-303       10
# HS-304       10
# CS-301       10
# CS-302       10
# TC-383       10
# MT-442       10
# EL-332        9
# CS-318        9
# CS-306        9
# CS-312       10
# CS-317       12
# CS-403       12
# CS-421       12
# CS-406       85
# CS-414       13
# CS-419       13
# CS-423       14
# CS-412       79
# CGPA          0
# dtype: int64

# %% [markdown]
# **So we can see that except PH-121, HS-101 and CS-105 rest all columns have null values.**

# %%
#Treating null values with mode
data['CY-105']=data['CY-105'].fillna(data['CY-105'].mode()[0])
data['HS-105/12']=data['HS-105/12'].fillna(data['HS-105/12'].mode()[0])
data['MT-111']=data['MT-111'].fillna(data['MT-111'].mode()[0])
data['CS-106']=data['CS-106'].fillna(data['CS-106'].mode()[0])
data['EL-102']=data['EL-102'].fillna(data['EL-102'].mode()[0])
data['EE-119']=data['EE-119'].fillna(data['EE-119'].mode()[0])
data['ME-107']=data['ME-107'].fillna(data['ME-107'].mode()[0])
data['CS-107']=data['CS-107'].fillna(data['CS-107'].mode()[0])
data['HS-205/20']=data['HS-205/20'].fillna(data['HS-205/20'].mode()[0])
data['MT-222']=data['MT-222'].fillna(data['MT-222'].mode()[0])
data['EE-222']=data['EE-222'].fillna(data['EE-222'].mode()[0])
data['MT-224']=data['MT-224'].fillna(data['MT-224'].mode()[0])
data['CS-210']=data['CS-210'].fillna(data['CS-210'].mode()[0])
data['CS-211']=data['CS-211'].fillna(data['CS-211'].mode()[0])
data['CS-203']=data['CS-203'].fillna(data['CS-203'].mode()[0])
data['CS-214']=data['CS-214'].fillna(data['CS-214'].mode()[0])
data['EE-217']=data['EE-217'].fillna(data['EE-217'].mode()[0])
data['CS-212']=data['CS-212'].fillna(data['CS-212'].mode()[0])
data['CS-215']=data['CS-215'].fillna(data['CS-215'].mode()[0])
data['MT-331']=data['MT-331'].fillna(data['MT-331'].mode()[0])
data['EF-303']=data['EF-303'].fillna(data['EF-303'].mode()[0])
data['HS-304']=data['HS-304'].fillna(data['HS-304'].mode()[0])
data['CS-301']=data['CS-301'].fillna(data['CS-301'].mode()[0])
data['CS-302']=data['CS-302'].fillna(data['CS-302'].mode()[0])
data['TC-383']=data['TC-383'].fillna(data['TC-383'].mode()[0])
data['MT-442']=data['MT-442'].fillna(data['MT-442'].mode()[0])
data['EL-332']=data['EL-332'].fillna(data['EL-332'].mode()[0])
data['CS-318']=data['CS-318'].fillna(data['CS-318'].mode()[0])
data['CS-306']=data['CS-306'].fillna(data['CS-306'].mode()[0])
data['CS-312']=data['CS-312'].fillna(data['CS-312'].mode()[0])
data['CS-317']=data['CS-317'].fillna(data['CS-317'].mode()[0])
data['CS-403']=data['CS-403'].fillna(data['CS-403'].mode()[0])
data['CS-421']=data['CS-421'].fillna(data['CS-421'].mode()[0])
data['CS-406']=data['CS-406'].fillna(data['CS-406'].mode()[0])
data['CS-414']=data['CS-414'].fillna(data['CS-414'].mode()[0])
data['CS-419']=data['CS-419'].fillna(data['CS-419'].mode()[0])
data['CS-423']=data['CS-423'].fillna(data['CS-423'].mode()[0])
data['CS-412']=data['CS-412'].fillna(data['CS-412'].mode()[0])

# %%
#Checking for null values
data.isna().sum()
# Out:
# Seat No.     0
# PH-121       0
# HS-101       0
# CY-105       0
# HS-105/12    0
# MT-111       0
# CS-105       0
# CS-106       0
# EL-102       0
# EE-119       0
# ME-107       0
# CS-107       0
# HS-205/20    0
# MT-222       0
# EE-222       0
# MT-224       0
# CS-210       0
# CS-211       0
# CS-203       0
# CS-214       0
# EE-217       0
# CS-212       0
# CS-215       0
# MT-331       0
# EF-303       0
# HS-304       0
# CS-301       0
# CS-302       0
# TC-383       0
# MT-442       0
# EL-332       0
# CS-318       0
# CS-306       0
# CS-312       0
# CS-317       0
# CS-403       0
# CS-421       0
# CS-406       0
# CS-414       0
# CS-419       0
# CS-423       0
# CS-412       0
# CGPA         0
# dtype: int64

# %% [markdown]
# **Now we can see that there are no null values present in the dataset**

# %%
#Dropping unwanted column
data=data.drop(['Seat No.'],axis=1)

# %%
data.head()
# Out:
#   PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119 ME-107  \
# 0     B-     D+     C-         C     C-     D+      D     C-     B-     C-
# 1      A      D     D+         D     B-      C      D      A     D+      D
# 2      A      B      A        B-     B+      A     B-     B+     A-     A-
# 3      D     C+     D+         D      D     A-     D+     C-      D     C+
# 4     A-     A-     A-        B+      A      A     A-     B+      A     A-
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 0  ...     C-     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1  ...     D+      D      C      D     A-     B-      C      C      B  2.008
# 2  ...      B      B      A      C      A      A      A     A-      A  3.608
# 3  ...     D+      C     D+     C-     B-      B     C+     C+     C+  1.906
# 4  ...     B-     B+     B+     B-     A-      A     A-     A-      A  3.448
#
# [5 rows x 42 columns]

# %% [markdown]
# **We can see that Seat No column have been removed from the dataset**

# %%
#Checking for duplicates
data.drop_duplicates(inplace=True)
data.shape
# Out:
# (571, 42)

# %% [markdown]
# **So by looking at the number of rows we can say it has not been reduced thats why there were no duplicates present in ther datset**

# %%
#Checking for the data types of column
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 571 entries, 0 to 570
# Data columns (total 42 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   PH-121     571 non-null    object
#  1   HS-101     571 non-null    object
#  2   CY-105     571 non-null    object
#  3   HS-105/12  571 non-null    object
#  4   MT-111     571 non-null    object
#  5   CS-105     571 non-null    object
#  6   CS-106     571 non-null    object
#  7   EL-102     571 non-null    object
#  8   EE-119     571 non-null    object
#  9   ME-107     571 non-null    object
#  10  CS-107     571 non-null    object
#  11  HS-205/20  571 non-null    object
#  12  MT-222     571 non-null    object
#  13  EE-222     571 non-null    object
#  14  MT-224     571 non-null    object
#  15  CS-210     571 non-null    object
#  16  CS-211     571 non-null    object
#  17  CS-203     571 non-null    object
#  18  CS-214     571 non-null    object
# ...

# %% [markdown]
# **Except CPGA column rest all columns have object datatype that is string.**

# %%
#Checking for unique value
data['PH-121'].unique()
# Out:
# array(['B-', 'A', 'D', 'A-', 'B+', 'B', 'C+', 'C', 'C-', 'D+', 'WU', 'A+',
#        'F'], dtype=object)

# %%
#Checking for the counts
data['PH-121'].value_counts()
# Out:
# A-    112
# A     111
# B+     61
# B      57
# B-     56
# D      44
# C      33
# C+     31
# D+     22
# A+     22
# C-     19
# WU      2
# F       1
# Name: PH-121, dtype: int64

# %%
data.groupby('CGPA')['PH-121'].value_counts()
# Out:
# CGPA   PH-121
# 0.800  F         1
# 0.998  D         1
# 1.000  D         1
# 1.092  WU        1
# 1.261  D         1
#                 ..
# 3.949  A+        1
# 3.963  A         1
# 3.970  A+        1
# 3.972  B+        1
# 3.985  A+        1
# Name: PH-121, Length: 552, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='PH-121',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got A negative and A grade in this department.**

# %%
#Plotting bar plot
sns.barplot(x='PH-121',y='CGPA',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that students who got A+ grade have CPGA close to 3.5.**

# %%
#Plotting Swarm plot
sns.swarmplot(x='PH-121',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['HS-101'].unique()
# Out:
# array(['D+', 'D', 'B', 'C+', 'A-', 'B-', 'C-', 'B+', 'C', 'A', 'A+', 'F'],
#       dtype=object)

# %%
#Checking for the counts
data['HS-101'].value_counts()
# Out:
# A-    82
# B-    78
# C     68
# B     63
# B+    59
# C-    50
# C+    47
# D     45
# A     38
# D+    36
# A+     4
# F      1
# Name: HS-101, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='HS-101',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got A negative and B Negative grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='HS-101',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='HS-101'',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['CY-105'].unique()
# Out:
# array(['C-', 'D+', 'A', 'A-', 'B', 'C+', 'B+', 'B-', 'C', 'D', 'WU', 'A+',
#        'F'], dtype=object)

# %%
#Checking for the counts
data['CY-105'].value_counts()
# Out:
# A     178
# A-    120
# B+     50
# B      49
# B-     42
# D      31
# A+     31
# C      19
# C+     17
# C-     16
# D+     14
# WU      3
# F       1
# Name: CY-105, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='CY-105',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got A grade followed by A negative grade in this department.**

# %%
#Plotting bar plot
sns.barplot(x='CY-105',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='CY-105',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['HS-105/12'].unique()
# Out:
# array(['C', 'D', 'B-', 'B+', 'D+', 'B', 'C-', 'C+', 'A-', 'A', 'WU', 'A+',
#        'F'], dtype=object)

# %%
#Checking for the counts
data['HS-105/12'].value_counts()
# Out:
# A     97
# A-    75
# B+    70
# B     57
# D     45
# C     41
# B-    40
# C+    39
# C-    36
# D+    34
# A+    34
# WU     2
# F      1
# Name: HS-105/12, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='HS-105/12',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got A grade followed by A negative grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='HS-105/12',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='HS-105/12',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['MT-111'].unique()
# Out:
# array(['C-', 'B-', 'B+', 'D', 'A', 'C+', 'A-', 'C', 'B', 'D+', 'A+', 'F',
#        'WU'], dtype=object)

# %%
#Checking for the counts
data['MT-111'].value_counts()
# Out:
# A-    107
# A     100
# B-     70
# B+     62
# B      55
# C-     39
# C+     33
# C      30
# D      26
# A+     23
# D+     21
# WU      3
# F       2
# Name: MT-111, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='MT-111',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got A neagtive grade followed by A grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='MT-111',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='MT-111',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['CS-105'].unique()
# Out:
# array(['D+', 'C', 'A', 'A-', 'B', 'B-', 'B+', 'C+', 'C-', 'A+', 'D'],
#       dtype=object)

# %%
#Checking for the counts
data['CS-105'].value_counts()
# Out:
# A     151
# A-    134
# B+     60
# B      51
# A+     43
# B-     38
# C+     23
# C      22
# C-     22
# D+     15
# D      12
# Name: CS-105, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='CS-105',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got A grade followed by A negative grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='CS-105',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='CS-105',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['CS-106'].unique()
# Out:
# array(['D', 'B-', 'D+', 'A-', 'C+', 'A', 'C-', 'C', 'B', 'B+', 'A+', 'F',
#        'WU'], dtype=object)

# %%
#Checking for the counts
data['CS-106'].value_counts()
# Out:
# A-    118
# B+    101
# B      96
# A      56
# B-     54
# C+     41
# D+     29
# C-     27
# D      24
# C      18
# A+      4
# WU      2
# F       1
# Name: CS-106, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='CS-106',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got A negative grade followed by B+ grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='CS-106',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='CS-106',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['EL-102'].unique()
# Out:
# array(['C-', 'A', 'B+', 'B', 'A-', 'B-', 'C', 'C+', 'D+', 'D', 'A+', 'WU',
#        'F'], dtype=object)

# %%
#Checking for the counts
data['EL-102'].value_counts()
# Out:
# A-    107
# A      92
# B+     69
# B      59
# B-     53
# D      38
# C+     35
# C-     32
# C      30
# A+     29
# D+     23
# WU      3
# F       1
# Name: EL-102, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='EL-102',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got A negative grade followed by A grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='EL-102',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='EL-102',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['EE-119'].unique()
# Out:
# array(['B-', 'D+', 'A-', 'D', 'A', 'B+', 'B', 'C-', 'C+', 'C', 'WU', 'A+'],
#       dtype=object)

# %%
#Checking for the counts
data['EE-119'].value_counts()
# Out:
# A-    139
# B+     83
# B      77
# A      68
# B-     48
# C      48
# C+     38
# D+     26
# C-     26
# D      11
# A+      6
# WU      1
# Name: EE-119, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='EE-119',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got A negative grade followed by B positive grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='EE-119',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='EE-119',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['ME-107'].unique()
# Out:
# array(['C-', 'D', 'A-', 'C+', 'B+', 'A', 'D+', 'C', 'B', 'B-', 'WU', 'F',
#        'A+'], dtype=object)

# %%
#Checking for the counts
data['ME-107'].value_counts()
# Out:
# A-    81
# A     77
# B+    68
# D     56
# B-    56
# B     50
# C     49
# C-    48
# C+    37
# D+    37
# A+     8
# WU     2
# F      2
# Name: ME-107, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='ME-107',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got A negative grade followed by A grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='ME-107',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='ME-107',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['CS-107'].unique()
# Out:
# array(['C-', 'B+', 'B-', 'D', 'C', 'A-', 'C+', 'D+', 'B', 'A', 'A+', 'I',
#        'WU', 'F'], dtype=object)

# %%
#Checking for the counts
data['CS-107'].value_counts()
# Out:
# A     107
# A-     81
# B+     57
# B      55
# C-     49
# B-     43
# A+     42
# D      38
# C+     34
# D+     31
# C      30
# WU      2
# I       1
# F       1
# Name: CS-107, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='CS-107',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got A grade followed by A negative grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='CS-107',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='CS-107',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['HS-205/20'].unique()
# Out:
# array(['B+', 'C+', 'A-', 'B', 'A', 'B-', 'D', 'WU', 'A+', 'C', 'D+', 'C-',
#        'F'], dtype=object)

# %%
#Checking for the counts
data['HS-205/20'].value_counts()
# Out:
# A-    155
# A     118
# B      97
# B+     89
# B-     36
# C+     33
# C      15
# C-     11
# D+      9
# D       3
# A+      2
# F       2
# WU      1
# Name: HS-205/20, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='HS-205/20',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got A negative grade followed by A grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='HS-205/20',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='HS-205/20',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['MT-222'].unique()
# Out:
# array(['D', 'B-', 'A', 'D+', 'C', 'B+', 'A-', 'B', 'C+', 'C-', 'WU', 'F',
#        'A+', 'W'], dtype=object)

# %%
#Checking for the counts
data['MT-222'].value_counts()
# Out:
# A-    91
# A     80
# D     66
# B     61
# B-    52
# D+    46
# C     43
# B+    42
# C+    39
# C-    30
# A+    16
# F      3
# WU     1
# W      1
# Name: MT-222, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='MT-222',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got A negative grade followed by A grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='MT-222',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='MT-222',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['EE-222'].unique()
# Out:
# array(['A-', 'C-', 'A', 'B-', 'B+', 'C+', 'D+', 'B', 'C', 'W', 'A+', 'D',
#        'F'], dtype=object)

# %%
#Checking for the counts
data['EE-222'].value_counts()
# Out:
# A     129
# A-    121
# B+     65
# B      53
# C      39
# B-     35
# A+     32
# C+     29
# D      25
# D+     21
# C-     16
# F       4
# W       2
# Name: EE-222, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='EE-222',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got A grade followed by A negative grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='EE-222',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='EE-222',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['MT-224'].unique()
# Out:
# array(['B-', 'D+', 'A', 'D', 'A-', 'C-', 'C', 'B+', 'C+', 'B', 'A+', 'WU',
#        'W', 'F'], dtype=object)

# %%
#Checking for the counts
data['MT-224'].value_counts()
# Out:
# A-    127
# A      80
# B+     65
# B      57
# B-     49
# C-     43
# C+     39
# D+     37
# D      31
# C      30
# A+     10
# WU      1
# W       1
# F       1
# Name: MT-224, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='MT-224',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got A negative grade followed by A grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='MT-224',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='MT-224',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['CS-210'].unique()
# Out:
# array(['C+', 'D+', 'A', 'C', 'A-', 'B+', 'B-', 'B', 'D', 'A+', 'C-', 'WU',
#        'W', 'F'], dtype=object)

# %%
#Checking for the counts
data['CS-210'].value_counts()
# Out:
# A-    140
# A     101
# B+     84
# B      59
# B-     58
# C      30
# C+     27
# C-     24
# D+     21
# D      12
# A+     12
# WU      1
# W       1
# F       1
# Name: CS-210, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='CS-210',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got A negative grade followed by A grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='CS-210',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='CS-210',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['CS-211'].unique()
# Out:
# array(['D+', 'D', 'A+', 'B+', 'B-', 'B', 'A-', 'C-', 'C+', 'C', 'A', 'WU',
#        'F', 'W'], dtype=object)

# %%
#Checking for the counts
data['CS-211'].value_counts()
# Out:
# A-    73
# A     67
# B-    60
# D+    56
# B+    56
# B     56
# C+    55
# C-    50
# C     39
# D     33
# A+    21
# F      3
# WU     1
# W      1
# Name: CS-211, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='CS-211',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got A negative grade followed by A grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='CS-211',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='CS-211',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['CS-203'].unique()
# Out:
# array(['D+', 'C', 'A', 'C+', 'A-', 'B+', 'B', 'B-', 'C-', 'D', 'A+', 'I',
#        'F'], dtype=object)

# %%
#Checking for the counts
data['CS-203'].value_counts()
# Out:
# A-    93
# A     81
# B     66
# C+    62
# B+    59
# B-    53
# D+    39
# C     35
# C-    35
# D     30
# A+    15
# F      2
# I      1
# Name: CS-203, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='CS-203',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got A negative grade followed by A grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='CS-203',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='CS-203',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['CS-214'].unique()
# Out:
# array(['D', 'A-', 'B', 'C', 'B-', 'C+', 'A', 'C-', 'B+', 'D+', 'I', 'F',
#        'A+'], dtype=object)

# %%
#Checking for the counts
data['CS-214'].value_counts()
# Out:
# C     82
# A-    73
# B     63
# C-    57
# B-    56
# A     56
# D+    47
# C+    46
# B+    45
# D     31
# A+    12
# F      2
# I      1
# Name: CS-214, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='CS-214',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got c grade followed by A neagative grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='CS-214',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='CS-214',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['EE-217'].unique()
# Out:
# array(['A', 'B-', 'D+', 'A-', 'A+', 'C', 'B+', 'B', 'C-', 'D', 'WU', 'F',
#        'C+'], dtype=object)

# %%
#Checking for the counts
data['EE-217'].value_counts()
# Out:
# A-    143
# A      97
# B+     70
# B      63
# B-     57
# C      36
# C+     29
# A+     22
# C-     20
# D+     19
# D      12
# F       2
# WU      1
# Name: EE-217, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='EE-217',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got A negative grade followed by A grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='EE-217',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='EE-217',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['CS-212'].unique()
# Out:
# array(['D', 'C', 'A-', 'C+', 'B-', 'D+', 'B+', 'B', 'A', 'C-', 'A+', 'WU'],
#       dtype=object)

# %%
#Checking for the counts
data['CS-212'].value_counts()
# Out:
# A-    107
# B+     86
# B      81
# B-     65
# C      44
# A      43
# D+     36
# C+     35
# C-     35
# D      33
# A+      4
# WU      2
# Name: CS-212, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='CS-212',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got A negative grade followed by B positive grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='CS-212',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='CS-212',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['CS-215'].unique()
# Out:
# array(['C-', 'D', 'A', 'A-', 'C+', 'C', 'B+', 'B-', 'D+', 'B', 'A+', 'WU',
#        'W', 'F'], dtype=object)

# %%
#Checking for the counts
data['CS-215'].value_counts()
# Out:
# A-    85
# A     68
# B     64
# B-    59
# C+    50
# B+    50
# C     48
# C-    47
# D     42
# D+    38
# A+    17
# WU     1
# W      1
# F      1
# Name: CS-215, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='CS-215',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got A negative grade followed by A grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='CS-215',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='CS-215',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['MT-331'].unique()
# Out:
# array(['C', 'D+', 'A', 'C+', 'B+', 'A-', 'B', 'B-', 'A+', 'D', 'C-', 'F'],
#       dtype=object)

# %%
#Checking for the counts
data['MT-331'].value_counts()
# Out:
# A     127
# A-    103
# B+     64
# B      57
# B-     46
# C-     32
# D+     31
# A+     30
# C      28
# C+     27
# D      22
# F       4
# Name: MT-331, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='MT-331',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got A grade followed by A negative grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='MT-331',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='MT-331',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['EF-303'].unique()
# Out:
# array(['C-', 'D', 'C+', 'B+', 'C', 'D+', 'A-', 'B-', 'A', 'B', 'WU', 'F'],
#       dtype=object)

# %%
#Checking for the counts
data['EF-303'].value_counts()
# Out:
# B     122
# B-     92
# C      61
# B+     59
# C+     58
# C-     56
# D+     49
# A-     38
# D      19
# A      14
# F       2
# WU      1
# Name: EF-303, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='EF-303',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got B grade followed by B negative grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='EF-303',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='EF-303',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['HS-304'].unique()
# Out:
# array(['C+', 'C-', 'A', 'B-', 'A-', 'B+', 'B', 'C', 'D', 'D+', 'A+', 'WU',
#        'F', 'W'], dtype=object)

# %%
#Checking for the counts
data['HS-304'].value_counts()
# Out:
# A-    138
# B      72
# B-     70
# B+     66
# C      58
# C+     53
# C-     33
# A      28
# D      20
# D+     19
# F       6
# A+      4
# WU      2
# W       2
# Name: HS-304, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='HS-304',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got A negative grade followed by B grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='HS-304',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='HS-304',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['CS-301'].unique()
# Out:
# array(['B', 'A-', 'B+', 'D', 'B-', 'D+', 'C', 'C+', 'C-', 'A', 'F', 'A+'],
#       dtype=object)

# %%
#Checking for the counts
data['CS-301'].value_counts()
# Out:
# A-    118
# B+     74
# B      71
# A      66
# B-     60
# C      41
# C+     37
# C-     36
# D      29
# D+     29
# A+      9
# F       1
# Name: CS-301, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='CS-301',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got A negative grade followed by B positive grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='CS-301',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='CS-301',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['CS-302'].unique()
# Out:
# array(['C', 'D+', 'A-', 'B-', 'C+', 'B', 'D', 'B+', 'A', 'C-', 'A+'],
#       dtype=object)

# %%
#Checking for the counts
data['CS-302'].value_counts()
# Out:
# A-    123
# B     102
# A      86
# B+     81
# B-     60
# C+     32
# C      28
# D      21
# C-     19
# D+     10
# A+      9
# Name: CS-302, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='CS-302',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got A negative grade followed by B grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='CS-302',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='CS-302',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['TC-383'].unique()
# Out:
# array(['C+', 'C-', 'B', 'D+', 'C', 'B+', 'B-', 'D', 'A-', 'A', 'F', 'A+'],
#       dtype=object)

# %%
#Checking for the counts
data['TC-383'].value_counts()
# Out:
# A     115
# A-     73
# B+     68
# B      59
# C+     44
# D+     44
# C-     42
# C      42
# B-     40
# A+     23
# D      20
# F       1
# Name: TC-383, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='TC-383',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got A grade followed by A negative  grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='TC-383',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='TC-383',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['MT-442'].unique()
# Out:
# array(['B+', 'C-', 'A', 'A-', 'B', 'A+', 'C+', 'B-', 'C', 'D+', 'D', 'F'],
#       dtype=object)

# %%
#Checking for the counts
data['MT-442'].value_counts()
# Out:
# A-    150
# A     130
# B+     65
# B      47
# A+     39
# B-     30
# C-     28
# C+     24
# C      24
# D      20
# D+     13
# F       1
# Name: MT-442, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='MT-442',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got A negative grade followed by A grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='MT-442',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='MT-442',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['EL-332'].unique()
# Out:
# array(['C', 'B+', 'D+', 'A-', 'B', 'A', 'B-', 'C-', 'C+', 'D', 'A+', 'F',
#        'WU'], dtype=object)

# %%
#Checking for the counts
data['EL-332'].value_counts()
# Out:
# A-    105
# A      76
# B+     68
# B      67
# B-     62
# C      49
# C+     38
# C-     32
# D+     22
# D      22
# A+     20
# F       9
# WU      1
# Name: EL-332, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='EL-332',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got A negative grade followed by A grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='EL-332',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='EL-332',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['CS-318'].unique()
# Out:
# array(['C-', 'A-', 'B+', 'B-', 'C', 'B', 'C+', 'D', 'D+', 'A', 'A+', 'WU',
#        'F', 'W'], dtype=object)

# %%
#Checking for the counts
data['CS-318'].value_counts()
# Out:
# A-    98
# B-    69
# B     68
# B+    65
# C     53
# C+    49
# A     42
# C-    40
# D     36
# D+    29
# F     10
# A+     6
# WU     5
# W      1
# Name: CS-318, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='CS-318',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got A negative grade followed by B negative grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='CS-318',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='CS-318',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['CS-306'].unique()
# Out:
# array(['C', 'D', 'A-', 'C-', 'B+', 'C+', 'B-', 'B', 'A', 'D+', 'A+', 'F',
#        'WU'], dtype=object)

# %%
#Checking for the counts
data['CS-306'].value_counts()
# Out:
# A-    129
# B+     75
# A      74
# B-     64
# B      53
# C-     40
# C      37
# C+     36
# D      31
# D+     18
# A+     10
# F       3
# WU      1
# Name: CS-306, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='CS-306',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got A negative grade followed by B positive grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='CS-306',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='CS-306',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['CS-312'].unique()
# Out:
# array(['C-', 'D+', 'B', 'B-', 'C', 'B+', 'C+', 'A-', 'D', 'A+', 'A', 'F',
#        'W', 'WU'], dtype=object)

# %%
#Checking for the counts
data['CS-312'].value_counts()
# Out:
# A+    103
# A      86
# A-     63
# D+     52
# C      48
# C-     44
# B+     42
# B      37
# C+     37
# B-     36
# D      19
# F       2
# W       1
# WU      1
# Name: CS-312, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='CS-312',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got A positive grade followed by A grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='CS-312',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='CS-312',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['CS-317'].unique()
# Out:
# array(['C-', 'D', 'B', 'C', 'B+', 'B-', 'A-', 'D+', 'C+', 'A', 'A+', 'F'],
#       dtype=object)

# %%
#Checking for the counts
data['CS-317'].value_counts()
# Out:
# B-    91
# B     75
# C     70
# A-    66
# B+    58
# C+    57
# A     47
# C-    41
# D+    34
# D     16
# A+     9
# F      7
# Name: CS-317, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='CS-317',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got B negative grade followed by B grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='CS-317',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='CS-317',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['CS-403'].unique()
# Out:
# array(['C-', 'C', 'A', 'D+', 'B+', 'C+', 'B-', 'A-', 'B', 'A+', 'D'],
#       dtype=object)

# %%
data['CS-403'].value_counts()
# Out:
# A     145
# A-    106
# B+     62
# B-     55
# B      54
# D+     35
# C      33
# C+     32
# C-     30
# A+     15
# D       4
# Name: CS-403, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='CS-403',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got A grade followed by A negative grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='CS-403',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='CS-403',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['CS-421'].unique()
# Out:
# array(['C-', 'D', 'C', 'B-', 'C+', 'B+', 'D+', 'B', 'A', 'A-', 'F', 'A+',
#        'W'], dtype=object)

# %%
#Checking for the counts
data['CS-421'].value_counts()
# Out:
# B     98
# B-    74
# C     68
# C+    61
# C-    60
# B+    60
# A-    47
# D+    36
# A     25
# D     21
# F     17
# A+     2
# W      2
# Name: CS-421, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='CS-421',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got B grade followed by B negative grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='CS-421',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='CS-421',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['CS-406'].unique()
# Out:
# array(['A-', 'A', 'B-', 'B', 'B+', 'C+', 'D', 'D+', 'C-', 'C', 'A+', 'F',
#        'W', 'WU'], dtype=object)

# %%
#Checking for the counts
data['CS-406'].value_counts()
# Out:
# A-    262
# A      79
# B+     64
# B      58
# B-     22
# C+     22
# C      19
# D+     14
# C-      8
# A+      8
# F       6
# D       5
# W       3
# WU      1
# Name: CS-406, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='CS-406',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got A negative grade followed by A grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='CS-406',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='CS-406',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['CS-414'].unique()
# Out:
# array(['A', 'B-', 'B', 'A-', 'B+', 'A+', 'C', 'C-', 'C+', 'F', 'D+', 'W',
#        'D'], dtype=object)

# %%
#Checking for the counts
data['CS-414'].value_counts()
# Out:
# A     189
# A-    156
# B+     62
# B      54
# B-     21
# A+     21
# C+     21
# C      20
# C-     12
# F       7
# D+      3
# D       3
# W       2
# Name: CS-414, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='CS-414',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got A grade followed by A negative grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='CS-414',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='CS-414',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['CS-419'].unique()
# Out:
# array(['C-', 'C', 'A', 'C+', 'A-', 'B+', 'B-', 'B', 'D+', 'A+', 'D', 'F'],
#       dtype=object)

# %%
#Checking for the counts
data['CS-419'].value_counts()
# Out:
# A-    133
# B      89
# B+     85
# B-     78
# A      56
# C+     46
# C      40
# C-     20
# D+     13
# D       7
# A+      2
# F       2
# Name: CS-419, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='CS-419',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got A negative grade followed by B grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='CS-419',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='CS-419',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['CS-423'].unique()
# Out:
# array(['B', 'C', 'A-', 'C+', 'B-', 'B+', 'C-', 'A', 'D+', 'D', 'A+', 'F'],
#       dtype=object)

# %%
#Checking for the counts
data['CS-423'].value_counts()
# Out:
# A-    136
# A      78
# B+     75
# B      65
# B-     56
# C      45
# C+     39
# C-     29
# D+     25
# D      15
# F       5
# A+      3
# Name: CS-423, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='CS-423',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got A negative grade followed by A grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='CS-423',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='CS-423',y='CGPA',data=data)
plt.show()

# %%
#Checking for unique value
data['CS-412'].unique()
# Out:
# array(['A-', 'B', 'A', 'C+', 'B+', 'C-', 'B-', 'A+', 'C', 'D+', 'F', 'W',
#        'D'], dtype=object)

# %%
#Checking for the counts
data['CS-412'].value_counts()
# Out:
# A-    236
# B+     80
# A      77
# B      65
# B-     37
# C+     24
# C      19
# D+      8
# C-      7
# F       6
# D       5
# A+      4
# W       3
# Name: CS-412, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='CS-412',data=data)
plt.show()

# %% [markdown]
# **In this plot we can see that most of the students got A negative grade followed by b positive grade in this department**

# %%
#Plotting bar plot
sns.barplot(x='CS-412',y='CGPA',data=data)
plt.show()

# %%
#Plotting Swarm plot
sns.swarmplot(x='CS-412',y='CGPA',data=data)
plt.show()

# %% [markdown]
# **Observation**
# * **By looking at all the plots it seems that each every department grades are important to predict the CPGA.**
# * **Because the CPGA is dependent on each and every department grades.**
# * **We cannot analyze the or predict the CPGA by taking only few features because as we know that the CPGA is calculated by considering the every years graded as well as the considering the every department grades.If we are dropping one of the department than it will hamper the CPGA.**
# * **By looking at the plots  it came into notice that only one department grade is not important if suppose a person is getting a A+ grade in one department and getting c grade in other department than it is goinf to affect his or her CPGA.**
# * **Analysis shows that all the features are important to predict the CPGA as it seems that all the features are very much related to the CPGA that is label.**

# %%
#Importing required libraries
from sklearn.preprocessing import LabelEncoder

# %%
#Encoding columns
lab_enc=LabelEncoder()
df1=lab_enc.fit_transform(data['PH-121'])
df2=lab_enc.fit_transform(data['HS-101'])
df3=lab_enc.fit_transform(data['CY-105'])
df4=lab_enc.fit_transform(data['HS-105/12'])
df5=lab_enc.fit_transform(data['MT-111'])
df6=lab_enc.fit_transform(data['CS-105'])
df7=lab_enc.fit_transform(data['CS-106'])
df8=lab_enc.fit_transform(data['EL-102'])
df9=lab_enc.fit_transform(data['EE-119'])
df10=lab_enc.fit_transform(data['ME-107'])
df11=lab_enc.fit_transform(data['CS-107'])
df12=lab_enc.fit_transform(data['HS-205/20'])
df13=lab_enc.fit_transform(data['MT-222'])
df14=lab_enc.fit_transform(data['EE-222'])
df15=lab_enc.fit_transform(data['MT-224'])
df16=lab_enc.fit_transform(data['CS-210'])
df17=lab_enc.fit_transform(data['CS-211'])
df18=lab_enc.fit_transform(data['CS-203'])
df19=lab_enc.fit_transform(data['CS-214'])
df20=lab_enc.fit_transform(data['EE-217'])
df21=lab_enc.fit_transform(data['CS-212'])
df22=lab_enc.fit_transform(data['CS-215'])
df23=lab_enc.fit_transform(data['MT-331'])
df24=lab_enc.fit_transform(data['EF-303'])
df25=lab_enc.fit_transform(data['HS-304'])
df26=lab_enc.fit_transform(data['CS-301'])
df27=lab_enc.fit_transform(data['CS-302'])
df28=lab_enc.fit_transform(data['TC-383'])
df29=lab_enc.fit_transform(data['MT-442'])
df30=lab_enc.fit_transform(data['EL-332'])
df31=lab_enc.fit_transform(data['CS-318'])
df32=lab_enc.fit_transform(data['CS-306'])
df33=lab_enc.fit_transform(data['CS-312'])
df34=lab_enc.fit_transform(data['CS-317'])
df35=lab_enc.fit_transform(data['CS-403'])
df36=lab_enc.fit_transform(data['CS-421'])
df37=lab_enc.fit_transform(data['CS-406'])
df38=lab_enc.fit_transform(data['CS-414'])
df39=lab_enc.fit_transform(data['CS-419'])
df40=lab_enc.fit_transform(data['CS-423'])
df41=lab_enc.fit_transform(data['CS-412'])

# %%
#Transfering the data
data['PH-121']=df1
data['HS-101']=df2
data['CY-105']=df3
data['HS-105/12']=df4
data['MT-111']=df5
data['CS-105']=df6
data['CS-106']=df7
data['EL-102']=df8
data['EE-119']=df9
data['ME-107']=df10
data['CS-107']=df11
data['HS-205/20']=df12
data['MT-222']=df13
data['EE-222']=df14
data['MT-224']=df15
data['CS-210']=df16
data['CS-211']=df17
data['CS-203']=df18
data['CS-214']=df19
data['EE-217']=df20
data['CS-212']=df21
data['CS-215']=df22
data['MT-331']=df23
data['EF-303']=df24
data['HS-304']=df25
data['CS-301']=df26
data['CS-302']=df27
data['TC-383']=df28
data['MT-442']=df29
data['EL-332']=df30
data['CS-318']=df31
data['CS-306']=df32
data['CS-312']=df33
data['CS-317']=df34
data['CS-403']=df35
data['CS-421']=df36
data['CS-406']=df37
data['CS-414']=df38
data['CS-419']=df39
data['CS-423']=df40
data['CS-412']=df41

# %%
#Checking whether the data is encoded or not
data.head()
# Out:
#    PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  EE-119  \
# 0       5      10       8          6       8      10       9       8       5
# 1       0       9      10          9       5       6       9       0      10
# 2       0       3       0          5       4       0       5       4       2
# 3       9       7      10          9       9       2      10       8       9
# 4       2       2       2          4       0       0       2       4       0
#
#    ME-107  ...  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  CS-419  \
# 0       8  ...       8       8       8       8       2       0       8
# 1       9  ...      10       9       6       9       2       5       6
# 2       2  ...       3       3       0       6       0       0       0
# 3       7  ...      10       6      10       8       5       3       7
# 4       2  ...       5       4       4       5       2       0       2
#
#    CS-423  CS-412   CGPA
# 0       3       2  2.205
# ...

# %%
#Checking Correlation
data.corr()
# Out:
#              PH-121    HS-101    CY-105  HS-105/12    MT-111    CS-105  \
# PH-121     1.000000  0.382436  0.557843   0.498561  0.468968  0.609990
# HS-101     0.382436  1.000000  0.335074   0.473132  0.432742  0.400713
# CY-105     0.557843  0.335074  1.000000   0.510123  0.538380  0.578573
# HS-105/12  0.498561  0.473132  0.510123   1.000000  0.494731  0.482406
# MT-111     0.468968  0.432742  0.538380   0.494731  1.000000  0.393684
# CS-105     0.609990  0.400713  0.578573   0.482406  0.393684  1.000000
# CS-106     0.293963  0.312019  0.378223   0.499093  0.500729  0.286324
# EL-102     0.423942  0.349412  0.447539   0.360304  0.555895  0.353949
# EE-119     0.579964  0.309697  0.467250   0.400303  0.409161  0.507357
# ME-107     0.533558  0.336545  0.464418   0.320137  0.471685  0.455470
# CS-107     0.477761  0.495906  0.481277   0.540405  0.488977  0.503239
# HS-205/20  0.296428  0.178344  0.261281   0.179766  0.328574  0.192982
# ...

# %%
#Plotting correlation
data.drop(['CGPA'],axis=1).corrwith(data['CGPA']).plot(kind='bar',grid=True,figsize=(20,10),title='correlation with CGPA')
plt.show()

# %% [markdown]
# **In this we can see that all the columns(features) are highly negatively correlated to the label that is CPGA. Further i will check it with the heatmap.**

# %%
#Plotting Heatmap
corr=data.corr().abs()
plt.figure(figsize=(30,20))
sns.heatmap(corr,annot=True)
plt.show()

# %% [markdown]
# **In this i am considering a percentage of 70% and above to find if there is any multicollinearity or not but  in this i did'nt find any value which is 70% and above,in this i am talking about feature vs feature. So this we came to know that there is no multicollinearity between the features.And about feature and label, so i can say that each and every column or features is correlated to the label.**

# %% [markdown]
# **Observation**
# * **After doing analysis i found that each and every column that is featurea are correlated to the label that is CPGA.**
# * **If i am using any feature selection method and dropping some of the columns than ot wont be good because the CPGA is a thing which is dependent on each and every department.And if we are dropping one of the department than we wont get a desired result.**
# * **So that is why i am not using any feature selection method.**

# %%
#Dividing dataset into features and label
#Features
x=data.drop(['CGPA'],axis=1)
#Label
y=data['CGPA']

# %%
#Importing required libraries
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
import xgboost as xgb
from sklearn.neighbors import KNeighborsRegressor
from sklearn import metrics
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %% [markdown]
# **Gradient Boosting**

# %%
#Initiating Gradient Boosting Regression
gb=GradientBoostingRegressor()

# %%
#using range fucntion to find the best random state using Logestic regression
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=i)
    gb.fit(x_train,y_train)
    pred=gb.predict(x_train)
    y_pred=gb.predict(x_test)
    print(f'at random state {i}, training accuracy is {metrics.r2_score(y_train,pred)*100}')
    print(f'at random state {i}, testing accuracy is {metrics.r2_score(y_test,y_pred)*100}')
    print('\n')
# Out:
# at random state 0, training accuracy is 99.61995846850668
# at random state 0, testing accuracy is 96.11783950165749
#
#
# at random state 1, training accuracy is 99.60628746302412
# at random state 1, testing accuracy is 96.26170468328526
#
#
# at random state 2, training accuracy is 99.55322702953777
# at random state 2, testing accuracy is 94.80986607629856
#
#
# at random state 3, training accuracy is 99.55773919975502
# at random state 3, testing accuracy is 96.17356334486955
#
#
# at random state 4, training accuracy is 99.62231931905359
# at random state 4, testing accuracy is 96.52035452251731
#
#
# at random state 5, training accuracy is 99.57167822486153
# at random state 5, testing accuracy is 96.18964406439872
#
#
# at random state 6, training accuracy is 99.58589990748922
# at random state 6, testing accuracy is 95.68504974354471
#
#
# at random state 7, training accuracy is 99.63470499055343
# at random state 7, testing accuracy is 95.4336140262317
#
#
# ...

# %% [markdown]
# **Taking the random state=75**

# %%
#since random state  has highest testing score,so taking random state as 
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=75)

# %%
#Training the Model
gb.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
pred=gb.predict(x_train)
y_pred=gb.predict(x_test)

# %%
#Printing the training and testing score
print('\n Training Score:',metrics.r2_score(y_train,pred)*100)
print('\n Testing Score:',metrics.r2_score(y_test,y_pred)*100)
# Out:
#  Training Score: 99.55119220324707
#
#  Testing Score: 97.51928466103595

# %%
train_accuracy=metrics.r2_score(y_train,pred)
test_accuracy=metrics.r2_score(y_test,y_pred)

# %%
#Checking cross validation score for Gradient Boosting
for j in range(2,6):
    cv_score=cross_val_score(gb,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f'at cross fold {j} the cv score is {cv_mean}and accuracy for the testing is {test_accuracy}')
    print('\n')
# Out:
# at cross fold 2 the cv score is 0.901566974063895and accuracy for the testing is 0.9751928466103595
#
#
# at cross fold 3 the cv score is 0.9063612467606689and accuracy for the testing is 0.9751928466103595
#
#
# at cross fold 4 the cv score is 0.8935416559362166and accuracy for the testing is 0.9751928466103595
#
#
# at cross fold 5 the cv score is 0.9310619271950549and accuracy for the testing is 0.9751928466103595

# %%
#mean absolute error
mean_absolute_error(y_test,y_pred)
# Out:
# 0.07012021830476918

# %%
#mean squared error
mean_squared_error(y_test,y_pred)
# Out:
# 0.008819582627312705

# %%
#Root mean squared error
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 0.09391263294846282

# %%
#Plotting the best fit line
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=y_pred,color='red')
plt.plot(y_test,y_test,color='blue')
plt.xlabel('Actual Charges',fontsize=10)
plt.ylabel('Predicted Charges',fontsize=10)
plt.show()

# %% [markdown]
# **Random Forest**

# %%
#Instantiating Random Forest
rf=RandomForestRegressor()

# %%
#since random state  has highest testing score,so taking random state as 
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=75)

# %%
#Training the Model
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
pred=rf.predict(x_train)
y_pred=rf.predict(x_test)

# %%
#Printing Training and testing score
print('\n Training Score:',metrics.r2_score(y_train,pred)*100)
print('\n Testing score:',metrics.r2_score(y_test,y_pred)*100)
# Out:
#  Training Score: 98.79691758745712
#
#  Testing score: 95.8860573648378

# %%
train_accuracy=metrics.r2_score(y_train,pred)
test_accuracy=metrics.r2_score(y_test,y_pred)

# %%
#Checking cross validation score for Random Forest
for j in range(2,6):
    cv_score=cross_val_score(rf,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f'at cross fold {j} the cv score is {cv_mean}and accuracy for the testing is {test_accuracy}')
    print('\n')
# Out:
# at cross fold 2 the cv score is 0.900470235214955and accuracy for the testing is 0.958860573648378
#
#
# at cross fold 3 the cv score is 0.8958915518480324and accuracy for the testing is 0.958860573648378
#
#
# at cross fold 4 the cv score is 0.886612413276566and accuracy for the testing is 0.958860573648378
#
#
# at cross fold 5 the cv score is 0.9046734174545834and accuracy for the testing is 0.958860573648378

# %%
#Mean Absolute Error
mean_absolute_error(y_test,y_pred)
# Out:
# 0.09122629370629368

# %%
#Mean Squared Error
mean_squared_error(y_test,y_pred)
# Out:
# 0.01462612675664334

# %%
#Root mean squared error
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 0.12093852470012746

# %%
#Plotting the best fit line
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=y_pred,color='red')
plt.plot(y_test,y_test,color='blue')
plt.xlabel('Actual Charges',fontsize=10)
plt.ylabel('Predicted Charges',fontsize=10)
plt.show()

# %% [markdown]
# **Ada Boost**

# %%
#Instantiating Ada Boost Regressor
ada=AdaBoostRegressor()

# %%
#since random state  has highest testing score,so taking random state as 
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=75)

# %%
#Training the data
ada.fit(x_train,y_train)
# Out:
# AdaBoostRegressor()

# %%
pred=ada.predict(x_train)
y_pred=ada.predict(x_test)

# %%
#Printing Training and Testing score
print('\n Training Score:',metrics.r2_score(y_train,pred)*100)
print('\n Testing Score:',metrics.r2_score(y_test,y_pred)*100)
# Out:
#  Training Score: 93.5060524921692
#
#  Testing Score: 91.045401975481

# %%
train_accuracy=metrics.r2_score(y_train,pred)
test_accuracy=metrics.r2_score(y_test,y_pred)

# %%
#Checking cross validation score for Ada Boost
for j in range(2,6):
    cv_score=cross_val_score(ada,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f'at cross fold {j} the cv score is {cv_mean}and accuracy for the testing is {test_accuracy}')
    print('\n')
# Out:
# at cross fold 2 the cv score is 0.8497688962316992and accuracy for the testing is 0.91045401975481
#
#
# at cross fold 3 the cv score is 0.8410966533269418and accuracy for the testing is 0.91045401975481
#
#
# at cross fold 4 the cv score is 0.8122446725145012and accuracy for the testing is 0.91045401975481
#
#
# at cross fold 5 the cv score is 0.8653983690309301and accuracy for the testing is 0.91045401975481

# %%
#Mean Absolute Error
mean_absolute_error(y_test,y_pred)
# Out:
# 0.1540967269612782

# %%
#Mean Squared Error
mean_squared_error(y_test,y_pred)
# Out:
# 0.03183590472117487

# %%
#Root mean squared error
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 0.1784261884398556

# %%
#Plotting the best fit line
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=y_pred,color='red')
plt.plot(y_test,y_test,color='blue')
plt.xlabel('Actual Charges',fontsize=10)
plt.ylabel('Predicted Charges',fontsize=10)
plt.show()

# %% [markdown]
# **XGBoost**

# %%
#Instantiating XGBoost
xgb=xgb.XGBRegressor()

# %%
#since random state  has highest testing score,so taking random state as 
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=75)

# %%
#Training data
xgb.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
pred=xgb.predict(x_train)
y_pred=xgb.predict(x_test)

# %%
#Printing Training and Testing Score
print('\n Training Score:',metrics.r2_score(y_train,pred)*100)
print('\n Testing Score:',metrics.r2_score(y_test,y_pred)*100)
# Out:
#  Training Score: 99.9998216820172
#
#  Testing Score: 93.40809953485244

# %%
train_accuracy=metrics.r2_score(y_train,pred)
test_accuracy=metrics.r2_score(y_test,y_pred)

# %%
#Checking cross validation score for XGBoost
for j in range(2,6):
    cv_score=cross_val_score(xgb,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f'at cross fold {j} the cv score is {cv_mean}and accuracy for the testing is {test_accuracy}')
    print('\n')
# Out:
# at cross fold 2 the cv score is 0.8368199152880833and accuracy for the testing is 0.9340809953485244
#
#
# at cross fold 3 the cv score is 0.8941573502751706and accuracy for the testing is 0.9340809953485244
#
#
# at cross fold 4 the cv score is 0.890234323790972and accuracy for the testing is 0.9340809953485244
#
#
# at cross fold 5 the cv score is 0.893786692873215and accuracy for the testing is 0.9340809953485244

# %%
#Mean Absolute Error
mean_absolute_error(y_test,y_pred)
# Out:
# 0.1100043056728123

# %%
#Mean Squared Error
mean_squared_error(y_test,y_pred)
# Out:
# 0.023435905728574416

# %%
#Root mean squared error
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 0.15308790196672764

# %%
#Plotting the best fit line
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=y_pred,color='red')
plt.plot(y_test,y_test,color='blue')
plt.xlabel('Actual Charges',fontsize=10)
plt.ylabel('Predicted Charges',fontsize=10)
plt.show()

# %%
#Making dataframe of all the models
data=pd.DataFrame({
    'Models':['Gradient Boosting','Random forest','Ada Boost','XGBoost'],
    'Training Score':[99.55,98.79,93.50,99.99],
    'Testing Score':[97.51,95.88,91.04,93.40],
    'Cross Val Score':[93.90,90.46,86.53,89.41],
    'RMSE':[0.09,0.12,0.17,0.15]
})
data
# Out:
#               Models  Training Score  Testing Score  Cross Val Score  RMSE
# 0  Gradient Boosting           99.55          97.51            93.90  0.09
# 1      Random forest           98.79          95.88            90.46  0.12
# 2          Ada Boost           93.50          91.04            86.53  0.17
# 3            XGBoost           99.99          93.40            89.41  0.15

# %% [markdown]
# **I will go with Gradient Boosting Regressor as the RMSE score of this model is very less as compared to other model.**

# %%
#Using Grid Search cv for hyperparameter tuning for Gradient Boosting
from sklearn.model_selection import GridSearchCV

# %%
param_grid=({
    'n_estimators': [200, 500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [4,5,6,7,8],
    'criterion' :['mse', 'friedman_mse','squared_error']
})

# %%
grid_search=GridSearchCV(gb,param_grid=param_grid,cv=5)

# %%
#Training
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'criterion': ['mse', 'friedman_mse', 'squared_error'],
#                          'max_depth': [4, 5, 6, 7, 8],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [200, 500]})

# %%
#best Parameters
grid_search.best_params_
# Out:
# {'criterion': 'friedman_mse',
#  'max_depth': 6,
#  'max_features': 'sqrt',
#  'n_estimators': 200}

# %%
#Training with the best parameters
gb=GradientBoostingRegressor(criterion='friedman_mse',max_depth=6,max_features='sqrt',n_estimators=200)
gb.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor(max_depth=6, max_features='sqrt', n_estimators=200)

# %%
#Printing the training and testing score
print('\n Training Score:',metrics.r2_score(y_train,pred)*100)
print('\n Testing Score:',metrics.r2_score(y_test,y_pred)*100)
# Out:
#  Training Score: 99.9998216820172
#
#  Testing Score: 93.40809953485244

# %% [markdown]
# **Observation**
# * **So after doing hyper parameter tuning it seems that the testing score is reduced to 93.40% from 97.51%.**
# * **Because of this i will consider the above model without hyperparameter tuning, imean to say the model in which i have not done hyperparameter tuning.**

# %%
#Cross validation SCore
cv_score=cross_val_score(gb,x,y,cv=5).mean()
cv_score
# Out:
# 0.9294226238385981

# %%
#saving the model
#Importing required libraries
import pickle
pickle.dump(gb,open('Grades project','wb'))
